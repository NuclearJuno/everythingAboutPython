# %% [markdown]
# # Trabalhando com Arquivos CSV
#
# Bem-vindo de volta! Vamos discutir como trabalhar com arquivos CSV em Python. Um arquivo com a extensão CSV é um arquivo de Valores Separados por Vírgula. Todos os arquivos CSV são arquivos de texto simples, contêm caracteres alfanuméricos e estruturam os dados contidos neles de forma tabular. Não confunda arquivos Excel com arquivos CSV, embora os arquivos CSV sejam formatados de maneira muito semelhante aos arquivos do Excel, eles não têm tipos de dados para seus valores, todos são strings sem fonte ou cor. Além disso, eles não têm planilhas da mesma forma que um arquivo do Excel. Python possui várias bibliotecas para trabalhar com arquivos do Excel, você pode conferi-las [aqui](http://www.python-excel.org/) e [aqui](https://www.xlwings.org/).
#
# Arquivos no formato CSV são geralmente usados para trocar dados, geralmente quando há uma grande quantidade de dados, entre diferentes aplicativos. Programas de banco de dados, software de análise e outras aplicações que armazenam grandes quantidades de informações (como contatos e dados de clientes) normalmente oferecem suporte ao formato CSV.
#
# Vamos explorar como podemos abrir um arquivo CSV com a biblioteca csv incorporada do Python.

# %% [markdown]
# ____
# ## Localização do Notebook + Criação de dados Fakes
#
# Execute **pwd** dentro de uma célula do caderno para descobrir onde seu caderno está localizado.

# %%
pwd
# Out:
# 'd:\\ESTUDOS\\git\\everythingAboutPython\\cda-python-master\\2. Criando Automações'

# %%
# !pip install faker
# Out:
# Collecting faker
#   Downloading Faker-25.6.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: python-dateutil>=2.4 in c:\users\juno\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from faker) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\juno\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.4->faker) (1.16.0)
# Downloading Faker-25.6.0-py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ------- -------------------------------- 0.4/1.8 MB 11.2 MB/s eta 0:00:01
#    ------------------- -------------------- 0.9/1.8 MB 11.2 MB/s eta 0:00:01
#    ------------------------------- -------- 1.4/1.8 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------------  1.8/1.8 MB 11.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 10.4 MB/s eta 0:00:00
# Installing collected packages: faker
# Successfully installed faker-25.6.0

# %% [markdown]
# Você pode criar um arquivo CSV com os headers fornecidos e 2000 linhas de dados aleatórios. Aqui está um exemplo de como você pode fazer isso em Python:

# %%
import csv
import random
import faker

# Inicializar o gerador de dados falsos
fake = faker.Faker()

# Headers do arquivo CSV
headers = ['id', 'first_name', 'last_name', 'email', 'gender', 'ip_address', 'city']

# %%
fake.first_name()
# Out:
# 'Nathan'

# %%
# Gerar 2000 linhas de dados aleatórios
data = []
for i in range(1, 2001):
    row = [i,
           fake.first_name(),
           fake.last_name(),
           fake.email(),
           random.choice(['Male', 'Female']),
           fake.ipv4(),
           fake.city()]
    data.append(row)

# %%
data
# Out:
# [[1,
#   'Johnny',
#   'Logan',
#   'brandon69@example.com',
#   'Male',
#   '193.108.22.36',
#   'Morrowberg'],
#  [2,
#   'Matthew',
#   'Duran',
#   'qfletcher@example.com',
#   'Female',
#   '70.97.228.249',
#   'Port Joseph'],
#  [3,
#   'Deanna',
#   'Clark',
#   'marklynch@example.net',
#   'Female',
#   '128.59.142.9',
#   'East Meghan'],
#  [4,
#   'Andrew',
#   'Le',
#   'jeffrey33@example.com',
#   'Female',
#   '105.221.202.160',
#   'South Nicholas'],
#  [5,
#   'George',
#   'Miles',
#   'shannonstevens@example.net',
#   'Female',
#   '207.123.119.202',
#   'East Mandy'],
#  [6,
#   'Ryan',
#   'Hart',
#   'timothyballard@example.org',
#   'Male',
#   '88.245.165.28',
#   'Lake Tiffanyshire'],
#  [7,
#   'Susan',
#   'Wheeler',
#   'hayesmichael@example.com',
#   'Male',
#   '53.17.50.60',
#   'Bergerchester'],
#  [8,
#   'Andre',
#   'Thomas',
#   'elizabethchase@example.org',
#   'Female',
#   '34.63.83.225',
#   'Lake Christybury'],
#  [9,
#   'Ashley',
#   'Flowers',
#   'vicki77@example.com',
#   'Female',
#   '221.57.89.1',
#   'Micheletown'],
#  [10,
#   'Katelyn',
#   'Mccall',
#   'pittmanbonnie@example.net',
#   'Female',
#   '107.25.28.117',
#   'Richardton'],
#  [11,
#   'Felicia',
#   'Craig',
#   'gallegosanthony@example.com',
#   'Male',
#   '131.141.36.222',
#   'Ashleyton'],
#  [12,
#   'Charles',
#   'Villa',
#   'alexanderpeters@example.com',
#   'Male',
#   '159.22.81.194',
#   'Sullivanhaven'],
#  [13,
#   'Kaitlyn',
#   'Snyder',
#   'wcosta@example.net',
#   'Female',
#   '185.218.190.6',
#   'Port Theresaburgh'],
#  [14,
#   'Tiffany',
#   'Morgan',
#   'christianshannon@example.org',
#   'Male',
#   '179.12.244.123',
#   'Lake Kaitlynshire'],
#  [15,
#   'Michelle',
#   'York',
#   'jesus13@example.com',
#   'Female',
#   '215.166.7.84',
#   'Port Erikside'],
#  [16,
#   'Julie',
#   'Anderson',
#   'andersonrichard@example.com',
#   'Male',
#   '91.152.135.245',
#   'New Derekburgh'],
#  [17,
#   'Robert',
#   'Moore',
#   'whitesteve@example.org',
#   'Female',
#   '98.67.17.39',
#   'Rachelhaven'],
#  [18,
#   'Charles',
#   'Cook',
#   'lopezshannon@example.org',
#   'Male',
#   '21.149.124.2',
#   'Whiteberg'],
#  [19,
#   'Mark',
#   'Cook',
#   'alvarezanthony@example.com',
#   'Female',
#   '112.219.100.4',
#   'South Frank'],
#  [20,
#   'Tracey',
#   'Green',
#   'rebeccamullen@example.org',
#   'Male',
#   '82.91.58.60',
#   'South Kevin'],
#  [21,
#   'Patricia',
#   'White',
#   'karen09@example.net',
#   'Female',
#   '30.209.18.250',
#   'Port Nicholas'],
#  [22,
#   'Norman',
#   'Allen',
#   'alexandria92@example.net',
#   'Male',
#   '76.32.123.207',
#   'Kristinville'],
#  [23,
#   'Chad',
#   'Jenkins',
#   'fergusonkelli@example.com',
#   'Male',
#   '195.147.62.39',
#   'Palmerfurt'],
#  [24,
#   'Michelle',
#   'Decker',
#   'lindseyjohnson@example.com',
#   'Female',
#   '189.14.23.86',
#   'Berryberg'],
#  [25,
#   'Susan',
#   'White',
#   'stephaniecarroll@example.com',
#   'Female',
#   '94.176.60.231',
#   'Nicholasbury'],
#  [26,
#   'Diana',
#   'Green',
#   'laurabrown@example.com',
#   'Female',
#   '2.251.219.67',
#   'Sarahburgh'],
#  [27,
#   'Cynthia',
#   'Jenkins',
#   'lauren75@example.net',
#   'Female',
#   '220.229.28.108',
#   'Johnsonmouth'],
#  [28,
#   'Andrea',
#   'Sloan',
#   'pamelafischer@example.org',
#   'Male',
#   '218.16.63.222',
#   'Matthewville'],
#  [29,
#   'Maria',
#   'Crawford',
#   'emma15@example.net',
#   'Female',
#   '178.195.231.104',
#   'Mckinneyton'],
#  [30,
#   'Shawn',
#   'Hancock',
#   'vdavis@example.net',
#   'Male',
#   '202.157.69.250',
#   'Michaelview'],
#  [31,
#   'Alexander',
#   'Brown',
#   'hhowell@example.com',
#   'Female',
#   '165.192.247.217',
#   'Larsenburgh'],
#  [32,
#   'Stephanie',
#   'Griffin',
#   'brobbins@example.com',
#   'Female',
#   '111.100.88.173',
#   'New Tanyabury'],
#  [33,
#   'Frank',
#   'Reed',
#   'castroaaron@example.org',
#   'Female',
#   '137.123.120.252',
#   'Parksfort'],
#  [34,
#   'Timothy',
#   'Meyers',
#   'ecummings@example.com',
#   'Female',
#   '141.213.14.5',
#   'New Robertview'],
#  [35,
#   'Anthony',
#   'Barr',
#   'willie34@example.net',
#   'Female',
#   '31.98.194.70',
#   'West Katherine'],
#  [36,
#   'Jeffrey',
#   'Perez',
#   'bethany29@example.org',
#   'Female',
#   '214.37.5.214',
#   'Aaronfort'],
#  [37,
#   'Michael',
#   'Brown',
#   'christopherneal@example.com',
#   'Female',
#   '210.195.66.201',
#   'Manuelberg'],
#  [38,
#   'Paul',
#   'Gutierrez',
#   'logangutierrez@example.org',
#   'Female',
#   '73.7.49.165',
#   'Gregoryview'],
#  [39,
#   'Jacob',
#   'Ho',
#   'bryantandrea@example.net',
#   'Female',
#   '64.125.69.160',
#   'Port Melissa'],
#  [40,
#   'Kimberly',
#   'Peterson',
#   'grobbins@example.org',
#   'Female',
#   '216.90.77.196',
#   'Stevenchester'],
#  [41,
#   'Matthew',
#   'Warren',
#   'pricedawn@example.com',
#   'Male',
#   '77.147.24.119',
#   'North Nicolechester'],
#  [42,
#   'David',
#   'Olson',
#   'olsenanne@example.net',
#   'Female',
#   '82.111.134.193',
#   'Robertomouth'],
#  [43,
#   'Holly',
#   'Cruz',
#   'pclayton@example.com',
#   'Male',
#   '97.9.27.145',
#   'Angelaport'],
#  [44,
#   'Zachary',
#   'Ford',
#   'ohernandez@example.com',
#   'Male',
#   '53.61.254.42',
#   'Port Brittneyview'],
#  [45,
#   'Christopher',
#   'Huynh',
#   'austin68@example.org',
#   'Female',
#   '222.108.109.66',
#   'Torresberg'],
#  [46,
#   'Deborah',
#   'Douglas',
#   'cthompson@example.net',
#   'Male',
#   '64.254.117.108',
#   'Bartonborough'],
#  [47,
#   'Carol',
#   'Beltran',
#   'paynerachel@example.org',
#   'Male',
#   '118.79.48.220',
#   'Lake Jeffrey'],
#  [48,
#   'John',
#   'Contreras',
#   'william68@example.com',
#   'Female',
#   '164.88.194.222',
#   'Stephensonport'],
#  [49,
#   'Susan',
#   'Alexander',
#   'derekbarrett@example.org',
#   'Male',
#   '106.62.10.57',
#   'Cooperberg'],
#  [50,
#   'Holly',
#   'Lozano',
#   'yharris@example.com',
#   'Male',
#   '2.49.207.194',
#   'Longton'],
#  [51,
#   'Jeffrey',
#   'Jackson',
#   'andersoncharles@example.com',
#   'Female',
#   '78.197.252.198',
#   'Lake Jonathan'],
#  [52,
#   'Charles',
#   'Robinson',
#   'owensdana@example.net',
#   'Male',
#   '46.70.36.79',
#   'Bradleybury'],
#  [53,
#   'Joann',
#   'Mitchell',
#   'jessica34@example.org',
#   'Female',
#   '172.53.86.99',
#   'Alanton'],
#  [54,
#   'Julia',
#   'Bowman',
#   'maureen49@example.org',
#   'Male',
#   '185.71.80.119',
#   'East Alicebury'],
#  [55,
#   'Mitchell',
#   'Hodge',
#   'joshuabenton@example.net',
#   'Male',
#   '6.221.97.26',
#   'Kelleyhaven'],
#  [56,
#   'Nicolas',
#   'Padilla',
#   'deborahhamilton@example.net',
#   'Female',
#   '151.163.69.163',
#   'Littlebury'],
#  [57,
#   'Mark',
#   'Munoz',
#   'davisjonathan@example.org',
#   'Male',
#   '175.240.78.198',
#   'Barberfurt'],
#  [58,
#   'Anita',
#   'Barrera',
#   'matthewhall@example.net',
#   'Female',
#   '10.238.118.112',
#   'East Rhondaborough'],
#  [59,
#   'John',
#   'Matthews',
#   'michaelwong@example.org',
#   'Female',
#   '207.190.254.160',
#   'East Rachel'],
#  [60,
#   'Gary',
#   'Roberts',
#   'hannahharmon@example.org',
#   'Female',
#   '17.72.186.0',
#   'Jennifertown'],
#  [61,
#   'Kendra',
#   'Bryant',
#   'gregory60@example.net',
#   'Female',
#   '195.217.80.121',
#   'Matthewmouth'],
#  [62,
#   'Ryan',
#   'Moses',
#   'eestes@example.net',
#   'Male',
#   '188.118.84.95',
#   'West Emily'],
#  [63,
#   'Victor',
#   'Sullivan',
#   'david42@example.org',
#   'Female',
#   '89.96.228.233',
#   'New Rebecca'],
#  [64,
#   'Brenda',
#   'Lewis',
#   'petersontodd@example.com',
#   'Female',
#   '218.177.239.151',
#   'Coleland'],
#  [65,
#   'Kevin',
#   'Mitchell',
#   'usalas@example.com',
#   'Male',
#   '4.8.238.201',
#   'Jessicaville'],
#  [66,
#   'Parker',
#   'Brown',
#   'zwatson@example.net',
#   'Male',
#   '65.169.183.226',
#   'Kendraland'],
#  [67,
#   'Dwayne',
#   'Benson',
#   'kleingeorge@example.com',
#   'Male',
#   '155.117.118.34',
#   'Laneport'],
#  [68,
#   'Danielle',
#   'Noble',
#   'chungsean@example.org',
#   'Male',
#   '130.47.230.190',
#   'Port Kelly'],
#  [69,
#   'Elizabeth',
#   'Holmes',
#   'daniel05@example.net',
#   'Female',
#   '222.61.142.68',
#   'Perezfort'],
#  [70,
#   'Brandi',
#   'Patrick',
#   'moralessamantha@example.net',
#   'Male',
#   '194.198.60.46',
#   'Suttonfort'],
#  [71,
#   'John',
#   'Williams',
#   'justin66@example.net',
#   'Male',
#   '142.84.247.170',
#   'Shortchester'],
#  [72,
#   'Joshua',
#   'Mcmahon',
#   'patriciaweiss@example.com',
#   'Female',
#   '100.24.29.186',
#   'Adambury'],
#  [73,
#   'Patricia',
#   'Booth',
#   'xking@example.org',
#   'Male',
#   '163.17.205.134',
#   'Adamston'],
#  [74,
#   'John',
#   'Cooke',
#   'waltermartinez@example.org',
#   'Female',
#   '216.159.146.0',
#   'Michelleshire'],
#  [75,
#   'Russell',
#   'Coleman',
#   'lanenatasha@example.org',
#   'Male',
#   '90.116.26.154',
#   'Lynnborough'],
#  [76,
#   'Alexandra',
#   'Solomon',
#   'susan00@example.org',
#   'Male',
#   '171.111.210.12',
#   'East Elizabeth'],
#  [77,
#   'Jo',
#   'Coleman',
#   'christophergonzalez@example.net',
#   'Male',
#   '172.124.82.255',
#   'Keithside'],
#  [78,
#   'John',
#   'Martin',
#   'lovegregory@example.com',
#   'Male',
#   '39.187.242.32',
#   'Lake Shannon'],
#  [79,
#   'Stephen',
#   'Bryant',
#   'williamconrad@example.com',
#   'Male',
#   '49.68.191.42',
#   'Crystalburgh'],
#  [80,
#   'Zachary',
#   'Glover',
#   'mitchellsheri@example.org',
#   'Female',
#   '210.16.40.93',
#   'Barreramouth'],
#  [81,
#   'William',
#   'Camacho',
#   'frazierhenry@example.net',
#   'Male',
#   '211.241.54.240',
#   'East Ronaldfurt'],
#  [82,
#   'Daniel',
#   'Buck',
#   'sherry63@example.org',
#   'Female',
#   '171.26.61.213',
#   'Amystad'],
#  [83,
#   'Austin',
#   'George',
#   'claire99@example.net',
#   'Female',
#   '212.118.132.192',
#   'East Thomas'],
#  [84,
#   'Ashley',
#   'Hendrix',
#   'monica81@example.org',
#   'Female',
#   '154.72.130.31',
#   'North Taylor'],
#  [85,
#   'Christian',
#   'Stewart',
#   'brian10@example.com',
#   'Male',
#   '81.63.48.73',
#   'Castilloport'],
#  [86,
#   'Thomas',
#   'Mcpherson',
#   'walter24@example.org',
#   'Female',
#   '101.234.128.44',
#   'Stevenberg'],
#  [87,
#   'Jeffrey',
#   'Cline',
#   'luis08@example.net',
#   'Female',
#   '202.106.244.201',
#   'Allenshire'],
#  [88,
#   'Kimberly',
#   'Peck',
#   'gmarshall@example.org',
#   'Female',
#   '62.125.228.181',
#   'Smithberg'],
#  [89,
#   'Brett',
#   'Johnson',
#   'arobertson@example.net',
#   'Male',
#   '210.94.115.86',
#   'South Taramouth'],
#  [90,
#   'Glenn',
#   'Baker',
#   'robertsgregory@example.net',
#   'Female',
#   '143.131.236.66',
#   'Karachester'],
#  [91,
#   'Kathy',
#   'Schmitt',
#   'wongalexander@example.org',
#   'Male',
#   '178.65.60.170',
#   'Thomasside'],
#  [92,
#   'Jessica',
#   'Noble',
#   'cindy58@example.com',
#   'Female',
#   '146.164.59.142',
#   'Cliffordberg'],
#  [93,
#   'Julia',
#   'Turner',
#   'keithbernard@example.com',
#   'Female',
#   '7.141.143.62',
#   'Angelaview'],
#  [94,
#   'Christopher',
#   'Mcdowell',
#   'stevenhenson@example.org',
#   'Male',
#   '173.122.251.40',
#   'East Barbaraview'],
#  [95,
#   'Cynthia',
#   'Wright',
#   'jweber@example.com',
#   'Female',
#   '72.89.178.228',
#   'Owensville'],
#  [96,
#   'Jose',
#   'Santiago',
#   'sabrina76@example.net',
#   'Female',
#   '191.133.110.129',
#   'South Shelby'],
#  [97,
#   'Teresa',
#   'Le',
#   'loverita@example.net',
#   'Male',
#   '53.185.243.165',
#   'Russoton'],
#  [98,
#   'Jeffrey',
#   'Baldwin',
#   'jamesjohnson@example.org',
#   'Female',
#   '26.15.147.217',
#   'Lake Ginastad'],
#  [99,
#   'Ian',
#   'Garcia',
#   'diazmonique@example.com',
#   'Male',
#   '180.4.201.27',
#   'Cummingston'],
#  [100,
#   'Emily',
#   'Johnson',
#   'david80@example.org',
#   'Male',
#   '175.25.61.146',
#   'Katherineport'],
#  [101,
#   'Joshua',
#   'Reed',
#   'jasonmorris@example.org',
#   'Male',
#   '138.70.184.144',
#   'New Kathryn'],
#  [102,
#   'Matthew',
#   'Smith',
#   'erica78@example.com',
#   'Female',
#   '78.176.3.148',
#   'Lake Shannon'],
#  [103,
#   'Abigail',
#   'Robles',
#   'davislouis@example.com',
#   'Male',
#   '124.145.31.123',
#   'East Patrick'],
#  [104,
#   'Richard',
#   'Foster',
#   'michaelcampbell@example.net',
#   'Female',
#   '167.189.4.151',
#   'Stevenburgh'],
#  [105,
#   'Paul',
#   'Stewart',
#   'thomasrose@example.org',
#   'Male',
#   '13.177.243.224',
#   'West Carolyn'],
#  [106,
#   'Whitney',
#   'Rowland',
#   'contrerasbrittany@example.org',
#   'Male',
#   '181.8.125.31',
#   'Alishafort'],
#  [107,
#   'Eric',
#   'Perkins',
#   'apatterson@example.org',
#   'Female',
#   '75.45.35.93',
#   'Kristinborough'],
#  [108,
#   'Lori',
#   'Jones',
#   'allisondodson@example.org',
#   'Male',
#   '221.38.11.202',
#   'West Nicholas'],
#  [109,
#   'Victoria',
#   'Holden',
#   'ericsmith@example.net',
#   'Male',
#   '85.243.49.252',
#   'Caroltown'],
#  [110,
#   'Diane',
#   'Moses',
#   'nicholasrodriguez@example.com',
#   'Male',
#   '131.75.50.79',
#   'Lake Robertfort'],
#  [111,
#   'Gary',
#   'Acosta',
#   'jeffrey51@example.com',
#   'Male',
#   '90.225.100.201',
#   'Shelbymouth'],
#  [112,
#   'Carol',
#   'Wilson',
#   'wallertaylor@example.com',
#   'Female',
#   '102.31.93.195',
#   'Morgantown'],
#  [113,
#   'Sandra',
#   'Adkins',
#   'nicholasweber@example.org',
#   'Male',
#   '37.188.206.47',
#   'New Cynthiaville'],
#  [114,
#   'Mark',
#   'Everett',
#   'sheilahughes@example.net',
#   'Male',
#   '1.171.160.240',
#   'Victoriahaven'],
#  [115,
#   'Cheryl',
#   'Martin',
#   'jessica22@example.net',
#   'Female',
#   '66.85.174.10',
#   'New Brianshire'],
#  [116,
#   'William',
#   'Mccormick',
#   'john57@example.com',
#   'Male',
#   '148.155.186.92',
#   'East William'],
#  [117,
#   'Ryan',
#   'Gray',
#   'davidchristina@example.org',
#   'Female',
#   '213.186.20.212',
#   'Gordonfurt'],
#  [118,
#   'Joshua',
#   'Baker',
#   'lindabryant@example.org',
#   'Female',
#   '93.10.150.77',
#   'New Robinside'],
#  [119,
#   'Tara',
#   'Martin',
#   'judiththomas@example.net',
#   'Female',
#   '3.96.168.51',
#   'Jessicachester'],
#  [120,
#   'William',
#   'Richardson',
#   'aliciagonzalez@example.com',
#   'Female',
#   '185.104.144.76',
#   'South Kristinberg'],
#  [121,
#   'Troy',
#   'Mason',
#   'taylorjacob@example.com',
#   'Female',
#   '82.59.147.151',
#   'West Davidtown'],
#  [122,
#   'Jessica',
#   'Porter',
#   'johnsonjoseph@example.com',
#   'Male',
#   '74.25.243.92',
#   'Lake Nicole'],
#  [123,
#   'Jessica',
#   'Nunez',
#   'qbaker@example.net',
#   'Male',
#   '112.173.44.56',
#   'Taylorfort'],
#  [124,
#   'Brandon',
#   'Simpson',
#   'fschmidt@example.org',
#   'Female',
#   '145.60.3.122',
#   'Davidland'],
#  [125,
#   'Sharon',
#   'Hernandez',
#   'lgordon@example.org',
#   'Male',
#   '134.30.137.177',
#   'Port Timothy'],
#  [126,
#   'Lucas',
#   'Preston',
#   'piercestephen@example.org',
#   'Male',
#   '149.250.217.45',
#   'East Wayne'],
#  [127,
#   'Tracy',
#   'Johnson',
#   'christopher21@example.com',
#   'Female',
#   '109.251.64.194',
#   'East Daniel'],
#  [128,
#   'Jennifer',
#   'Osborne',
#   'abanks@example.org',
#   'Male',
#   '31.141.97.82',
#   'Harrisshire'],
#  [129,
#   'John',
#   'Day',
#   'odominguez@example.net',
#   'Male',
#   '99.71.37.156',
#   'New Patrickburgh'],
#  [130,
#   'Madison',
#   'Stewart',
#   'trodriguez@example.org',
#   'Male',
#   '114.200.88.210',
#   'Richardfurt'],
#  [131,
#   'David',
#   'Webb',
#   'mark09@example.net',
#   'Male',
#   '209.176.69.117',
#   'Cooperchester'],
#  [132,
#   'Andrea',
#   'Marshall',
#   'lisacarter@example.net',
#   'Male',
#   '24.19.154.152',
#   'Nicholsland'],
#  [133,
#   'Alfred',
#   'Mooney',
#   'gregory63@example.net',
#   'Male',
#   '124.209.62.75',
#   'North Scottton'],
#  [134,
#   'Amber',
#   'Humphrey',
#   'acampbell@example.net',
#   'Male',
#   '190.76.93.58',
#   'Markfurt'],
#  [135,
#   'Tyler',
#   'Gibson',
#   'pwebster@example.org',
#   'Female',
#   '53.244.115.11',
#   'Wrightborough'],
#  [136,
#   'Michael',
#   'Herrera',
#   'vlin@example.org',
#   'Female',
#   '143.116.52.9',
#   'Williamsfurt'],
#  [137,
#   'Justin',
#   'Vega',
#   'megannorris@example.com',
#   'Male',
#   '153.196.6.91',
#   'New Corey'],
#  [138,
#   'Elizabeth',
#   'Carter',
#   'zacharythomas@example.com',
#   'Male',
#   '111.105.172.137',
#   'Harrisbury'],
#  [139,
#   'Francis',
#   'Wallace',
#   'michael25@example.org',
#   'Male',
#   '181.219.195.144',
#   'Mayville'],
#  [140,
#   'Laura',
#   'Chavez',
#   'cschneider@example.net',
#   'Male',
#   '118.117.47.215',
#   'Woodtown'],
#  [141,
#   'Carol',
#   'Ruiz',
#   'tylerblanchard@example.net',
#   'Female',
#   '166.23.83.230',
#   'New Sarah'],
#  [142,
#   'Roger',
#   'Long',
#   'nicholassharp@example.net',
#   'Male',
#   '89.138.245.151',
#   'South Rosefurt'],
#  [143,
#   'Michele',
#   'Sharp',
#   'steve22@example.org',
#   'Female',
#   '208.89.69.209',
#   'New Jennifertown'],
#  [144,
#   'Mark',
#   'Parsons',
#   'dana41@example.net',
#   'Male',
#   '180.50.151.125',
#   'East Johnfurt'],
#  [145,
#   'James',
#   'Beck',
#   'reiddeborah@example.org',
#   'Female',
#   '65.204.140.46',
#   'Brownshire'],
#  [146,
#   'William',
#   'Adams',
#   'walkereric@example.com',
#   'Male',
#   '222.21.241.28',
#   'South Patricia'],
#  [147,
#   'David',
#   'Stewart',
#   'sjones@example.com',
#   'Male',
#   '193.224.55.150',
#   'Hardyborough'],
#  [148,
#   'Amanda',
#   'Anderson',
#   'hsmith@example.net',
#   'Female',
#   '53.76.88.231',
#   'South Alexberg'],
#  [149,
#   'Alexandra',
#   'Vaughan',
#   'vcruz@example.net',
#   'Male',
#   '134.92.192.102',
#   'West Amyfurt'],
#  [150,
#   'Leah',
#   'Abbott',
#   'olsondenise@example.net',
#   'Male',
#   '62.99.60.231',
#   'North Suzanne'],
#  [151,
#   'Diana',
#   'Lawson',
#   'kelleyamber@example.net',
#   'Female',
#   '71.8.19.205',
#   'Port Michelle'],
#  [152,
#   'Ryan',
#   'Miles',
#   'elizabeth98@example.net',
#   'Male',
#   '181.185.202.107',
#   'West Mary'],
#  [153,
#   'Timothy',
#   'Horn',
#   'chavezelizabeth@example.org',
#   'Male',
#   '218.138.243.45',
#   'North Dianeburgh'],
#  [154,
#   'Frank',
#   'Bush',
#   'stricklandjohn@example.net',
#   'Male',
#   '187.157.205.141',
#   'South Chrisshire'],
#  [155,
#   'Cassandra',
#   'Williams',
#   'johnsonjennifer@example.com',
#   'Male',
#   '198.184.142.2',
#   'Thomasfort'],
#  [156,
#   'Justin',
#   'Jones',
#   'david68@example.com',
#   'Male',
#   '122.75.56.99',
#   'East Christopherfurt'],
#  [157,
#   'Sean',
#   'Clark',
#   'briggsashley@example.org',
#   'Female',
#   '152.155.56.60',
#   'Lake Paul'],
#  [158,
#   'Caitlin',
#   'Tucker',
#   'jacksonsara@example.org',
#   'Male',
#   '125.85.232.112',
#   'West Mistyfort'],
#  [159,
#   'Tina',
#   'Riddle',
#   'dbrooks@example.org',
#   'Female',
#   '65.213.246.192',
#   'Careyshire'],
#  [160,
#   'Shirley',
#   'Woods',
#   'william35@example.org',
#   'Female',
#   '189.81.108.62',
#   'South Jacob'],
#  [161,
#   'Ricardo',
#   'Wright',
#   'xhenry@example.org',
#   'Female',
#   '10.17.82.99',
#   'West Ricardo'],
#  [162,
#   'Maxwell',
#   'Boyd',
#   'dayclaudia@example.com',
#   'Female',
#   '25.191.148.109',
#   'Port Nicolefort'],
#  [163,
#   'Melvin',
#   'Park',
#   'ydickson@example.org',
#   'Female',
#   '121.139.231.252',
#   'Lake Vincent'],
#  [164,
#   'Amy',
#   'Jones',
#   'rlowe@example.org',
#   'Female',
#   '27.76.154.236',
#   'Lake Matthewtown'],
#  [165,
#   'Andrew',
#   'Walker',
#   'wilsonnathan@example.net',
#   'Female',
#   '9.240.221.96',
#   'Port James'],
#  [166,
#   'Taylor',
#   'Matthews',
#   'knapparthur@example.com',
#   'Male',
#   '198.217.192.124',
#   'Pageburgh'],
#  [167,
#   'Gregory',
#   'French',
#   'derrick71@example.com',
#   'Male',
#   '175.237.27.53',
#   'Lake Jennifer'],
#  [168,
#   'Donna',
#   'Collins',
#   'angela15@example.com',
#   'Male',
#   '11.211.160.111',
#   'Kennedyfurt'],
#  [169,
#   'Mark',
#   'Thompson',
#   'william94@example.com',
#   'Male',
#   '95.166.242.0',
#   'New Jeffrey'],
#  [170,
#   'Michael',
#   'Lowe',
#   'bmurphy@example.org',
#   'Male',
#   '198.232.182.150',
#   'West Cynthia'],
#  [171,
#   'Sonya',
#   'Riddle',
#   'zwilliams@example.net',
#   'Male',
#   '83.249.18.175',
#   'West Jacquelinehaven'],
#  [172,
#   'Brandon',
#   'Moore',
#   'tim49@example.net',
#   'Male',
#   '121.167.248.174',
#   'Kyleton'],
#  [173,
#   'Amber',
#   'Murphy',
#   'mannmelissa@example.org',
#   'Male',
#   '221.34.240.115',
#   'South Latoyachester'],
#  [174,
#   'Alicia',
#   'Gill',
#   'tylerbennett@example.net',
#   'Male',
#   '14.238.87.37',
#   'Christopherhaven'],
#  [175,
#   'Evelyn',
#   'Jones',
#   'jessicablankenship@example.net',
#   'Male',
#   '152.159.91.63',
#   'East Lisa'],
#  [176,
#   'Scott',
#   'Bailey',
#   'tracy53@example.com',
#   'Female',
#   '96.157.101.128',
#   'Heathburgh'],
#  [177,
#   'Nina',
#   'Johnson',
#   'james69@example.org',
#   'Female',
#   '139.170.52.199',
#   'Sullivantown'],
#  [178,
#   'Daniel',
#   'Kim',
#   'claytonshort@example.org',
#   'Male',
#   '179.100.249.190',
#   'West Lisaburgh'],
#  [179,
#   'Monique',
#   'Burns',
#   'simonglen@example.org',
#   'Male',
#   '75.98.37.24',
#   'Walterville'],
#  [180,
#   'Lauren',
#   'Stout',
#   'chubbard@example.net',
#   'Male',
#   '107.202.146.162',
#   'North Sandyside'],
#  [181,
#   'Matthew',
#   'Pratt',
#   'yriley@example.net',
#   'Female',
#   '152.79.33.146',
#   'New Gabriel'],
#  [182,
#   'Anthony',
#   'Hughes',
#   'dbrown@example.com',
#   'Male',
#   '177.245.78.145',
#   'East Andrewmouth'],
#  [183,
#   'Leslie',
#   'Shaw',
#   'adam81@example.org',
#   'Female',
#   '88.33.140.197',
#   'Nunezton'],
#  [184,
#   'Robert',
#   'Hogan',
#   'kristapoole@example.com',
#   'Male',
#   '191.247.122.139',
#   'Lake Victoriaton'],
#  [185,
#   'Tonya',
#   'Fisher',
#   'mlewis@example.org',
#   'Male',
#   '66.128.194.160',
#   'Jacobsborough'],
#  [186,
#   'Michael',
#   'Clark',
#   'williamsjames@example.net',
#   'Female',
#   '188.141.2.5',
#   'South Jasonside'],
#  [187,
#   'Jane',
#   'Mcpherson',
#   'amandajensen@example.net',
#   'Female',
#   '83.254.171.90',
#   'West Lisa'],
#  [188,
#   'Cesar',
#   'Brown',
#   'wallacejulie@example.net',
#   'Male',
#   '70.166.228.35',
#   'Lake Morgan'],
#  [189,
#   'Emily',
#   'Solis',
#   'summersana@example.com',
#   'Female',
#   '151.254.135.72',
#   'Joelfurt'],
#  [190,
#   'Max',
#   'Scott',
#   'davidsanford@example.org',
#   'Female',
#   '5.69.118.175',
#   'Johnland'],
#  [191,
#   'Brendan',
#   'Zamora',
#   'sarah85@example.net',
#   'Female',
#   '216.252.215.22',
#   'Justinmouth'],
#  [192,
#   'Gregory',
#   'Carpenter',
#   'wramirez@example.com',
#   'Female',
#   '218.81.143.45',
#   'Corystad'],
#  [193,
#   'Emily',
#   'Massey',
#   'desireedavis@example.org',
#   'Female',
#   '88.11.114.177',
#   'Nathanstad'],
#  [194,
#   'Lindsey',
#   'Johnson',
#   'nicholas60@example.com',
#   'Female',
#   '107.100.216.131',
#   'Bernardview'],
#  [195,
#   'Judith',
#   'Ramos',
#   'arthurkemp@example.net',
#   'Female',
#   '207.52.169.47',
#   'Julieshire'],
#  [196,
#   'Cody',
#   'Hernandez',
#   'donnarodgers@example.org',
#   'Female',
#   '11.62.186.70',
#   'Lake Terri'],
#  [197,
#   'Kristin',
#   'Gonzalez',
#   'campbelljennifer@example.net',
#   'Female',
#   '136.173.192.76',
#   'South Charles'],
#  [198,
#   'Sheila',
#   'Roberts',
#   'gateskaren@example.com',
#   'Female',
#   '75.233.113.51',
#   'New Lauren'],
#  [199,
#   'Stephen',
#   'Blake',
#   'scott09@example.com',
#   'Female',
#   '217.201.233.145',
#   'Port Williammouth'],
#  [200,
#   'Daniel',
#   'Holt',
#   'vincentblackwell@example.net',
#   'Male',
#   '184.241.43.163',
#   'Port Amy'],
#  [201,
#   'Jeremy',
#   'Rice',
#   'jamesbrock@example.com',
#   'Female',
#   '215.248.206.168',
#   'Allenbury'],
#  [202,
#   'Tammy',
#   'Mccarthy',
#   'andrewschmidt@example.net',
#   'Female',
#   '136.174.181.28',
#   'Christinestad'],
#  [203,
#   'Laura',
#   'Shelton',
#   'watkinsjon@example.net',
#   'Male',
#   '187.194.239.105',
#   'Patrickville'],
#  [204,
#   'Jennifer',
#   'Silva',
#   'adrianjuarez@example.com',
#   'Male',
#   '211.160.156.210',
#   'New Timothy'],
#  [205,
#   'Angela',
#   'Sosa',
#   'kristinhendricks@example.net',
#   'Female',
#   '54.125.137.236',
#   'Port Justin'],
#  [206,
#   'Alexis',
#   'Fisher',
#   'househeather@example.com',
#   'Female',
#   '190.21.60.221',
#   'Port Timothy'],
#  [207,
#   'Michael',
#   'Turner',
#   'dberry@example.org',
#   'Male',
#   '17.253.44.114',
#   'West Keith'],
#  [208,
#   'Tracy',
#   'Mccann',
#   'kevin93@example.net',
#   'Female',
#   '182.177.108.136',
#   'West Christinaview'],
#  [209,
#   'Jennifer',
#   'Parker',
#   'eelliott@example.com',
#   'Female',
#   '170.227.18.158',
#   'Lake Benjamin'],
#  [210,
#   'Nicholas',
#   'Johnson',
#   'michellemartin@example.com',
#   'Female',
#   '116.214.73.199',
#   'Lake Amy'],
#  [211,
#   'Daniel',
#   'Daniel',
#   'sarahwilkins@example.org',
#   'Female',
#   '147.226.126.85',
#   'Lake Matthewland'],
#  [212,
#   'Dennis',
#   'Miller',
#   'hcollier@example.net',
#   'Male',
#   '162.10.208.102',
#   'West Brittany'],
#  [213,
#   'Sandra',
#   'Lee',
#   'fsimpson@example.com',
#   'Male',
#   '107.218.14.96',
#   'Lake Yvonnemouth'],
#  [214,
#   'Jason',
#   'Clark',
#   'briannacooley@example.org',
#   'Female',
#   '59.155.193.183',
#   'Tuckerland'],
#  [215,
#   'Jeffrey',
#   'Thompson',
#   'kelseythomas@example.org',
#   'Male',
#   '215.41.106.76',
#   'Donnaberg'],
#  [216,
#   'Summer',
#   'Bentley',
#   'pgarcia@example.org',
#   'Female',
#   '48.112.67.30',
#   'Benjaminshire'],
#  [217,
#   'Shane',
#   'White',
#   'davistina@example.com',
#   'Male',
#   '191.171.35.85',
#   'Schneiderhaven'],
#  [218,
#   'Henry',
#   'Hardy',
#   'wadetodd@example.com',
#   'Male',
#   '47.204.5.134',
#   'Mitchellton'],
#  [219,
#   'Zachary',
#   'Martin',
#   'jonathanglenn@example.com',
#   'Male',
#   '99.114.23.74',
#   'North Sarastad'],
#  [220,
#   'Todd',
#   'Mcmillan',
#   'steinjulia@example.org',
#   'Male',
#   '117.120.98.193',
#   'Arnoldfurt'],
#  [221,
#   'Julie',
#   'Kelley',
#   'kpadilla@example.com',
#   'Male',
#   '183.190.102.1',
#   'Tanyaton'],
#  [222,
#   'Melissa',
#   'Berry',
#   'rebeccasmith@example.org',
#   'Male',
#   '213.32.226.88',
#   'Joneshaven'],
#  [223,
#   'Andrew',
#   'Kim',
#   'smithchristopher@example.com',
#   'Male',
#   '154.133.189.14',
#   'Angelaberg'],
#  [224,
#   'Laura',
#   'Stewart',
#   'samanthabarker@example.org',
#   'Male',
#   '125.163.227.81',
#   'West Ryan'],
#  [225,
#   'Sheri',
#   'Hoffman',
#   'kennethburton@example.com',
#   'Male',
#   '185.175.149.110',
#   'Lake Cole'],
#  [226,
#   'Bradley',
#   'Kim',
#   'victoriajenkins@example.net',
#   'Male',
#   '141.22.40.93',
#   'West Jacqueline'],
#  [227,
#   'Anthony',
#   'French',
#   'katherine77@example.com',
#   'Female',
#   '150.2.110.18',
#   'Nataliechester'],
#  [228,
#   'Kimberly',
#   'Ballard',
#   'deleonmelinda@example.org',
#   'Female',
#   '221.151.31.176',
#   'New Philip'],
#  [229,
#   'Christian',
#   'White',
#   'cduncan@example.org',
#   'Female',
#   '54.100.215.171',
#   'Juliaton'],
#  [230,
#   'Robert',
#   'Doyle',
#   'richard91@example.net',
#   'Female',
#   '75.90.89.123',
#   'Lake Markview'],
#  [231,
#   'Nicholas',
#   'Wells',
#   'whoffman@example.net',
#   'Female',
#   '116.91.255.245',
#   'Lake Jordanberg'],
#  [232,
#   'Kaitlin',
#   'Elliott',
#   'raymond19@example.org',
#   'Male',
#   '11.152.34.14',
#   'North Brianmouth'],
#  [233,
#   'Dana',
#   'Rios',
#   'franciscomoses@example.com',
#   'Female',
#   '38.214.104.219',
#   'Seanshire'],
#  [234,
#   'Nathan',
#   'Strong',
#   'hturner@example.com',
#   'Female',
#   '143.203.220.120',
#   'Wilsonborough'],
#  [235,
#   'Patricia',
#   'Moore',
#   'kcampbell@example.net',
#   'Female',
#   '158.192.170.103',
#   'Claytonport'],
#  [236,
#   'Karen',
#   'Harrison',
#   'pbrown@example.com',
#   'Male',
#   '157.228.180.245',
#   'Angelabury'],
#  [237,
#   'Jacqueline',
#   'Taylor',
#   'yacosta@example.net',
#   'Female',
#   '160.34.102.237',
#   'Port Jillhaven'],
#  [238,
#   'Willie',
#   'Ford',
#   'gmoss@example.com',
#   'Female',
#   '166.213.155.241',
#   'Reedburgh'],
#  [239,
#   'Jessica',
#   'Hughes',
#   'bensonmichael@example.net',
#   'Female',
#   '118.131.81.60',
#   'Port Steveville'],
#  [240,
#   'Beverly',
#   'Bennett',
#   'heather24@example.org',
#   'Male',
#   '84.42.86.112',
#   'New Matthewfort'],
#  [241,
#   'David',
#   'Thompson',
#   'eric32@example.com',
#   'Female',
#   '125.98.28.122',
#   'Port Charles'],
#  [242,
#   'Larry',
#   'Lucas',
#   'henry95@example.com',
#   'Female',
#   '174.223.59.115',
#   'Martinmouth'],
#  [243,
#   'Joshua',
#   'Brown',
#   'sandra98@example.net',
#   'Female',
#   '91.191.179.115',
#   'Justinport'],
#  [244,
#   'Wanda',
#   'Montoya',
#   'shawnfischer@example.org',
#   'Male',
#   '173.158.204.225',
#   'Travisshire'],
#  [245,
#   'Robert',
#   'Watkins',
#   'allen52@example.org',
#   'Male',
#   '135.19.124.85',
#   'Aguirreland'],
#  [246,
#   'Susan',
#   'Johns',
#   'williamwelch@example.com',
#   'Female',
#   '92.20.3.3',
#   'New Laurafort'],
#  [247,
#   'Kendra',
#   'Burke',
#   'mark23@example.com',
#   'Female',
#   '9.113.54.203',
#   'Robinsonville'],
#  [248,
#   'Anthony',
#   'Bishop',
#   'adam74@example.com',
#   'Female',
#   '106.1.198.133',
#   'Murphyside'],
#  [249,
#   'James',
#   'Roth',
#   'angela79@example.net',
#   'Female',
#   '61.123.212.251',
#   'Youngport'],
#  [250,
#   'Debbie',
#   'Smith',
#   'seth70@example.net',
#   'Female',
#   '30.77.37.207',
#   'Brianborough'],
#  [251,
#   'William',
#   'Butler',
#   'gkemp@example.org',
#   'Female',
#   '117.253.142.27',
#   'West Stephaniestad'],
#  [252,
#   'Timothy',
#   'Williamson',
#   'hector07@example.net',
#   'Male',
#   '84.22.140.57',
#   'South Cynthia'],
#  [253,
#   'Wendy',
#   'Walker',
#   'jonathan88@example.net',
#   'Male',
#   '160.46.229.48',
#   'Davisstad'],
#  [254,
#   'Cynthia',
#   'Cobb',
#   'ericphillips@example.org',
#   'Female',
#   '65.62.189.242',
#   'Cameronmouth'],
#  [255,
#   'Dylan',
#   'Smith',
#   'mrobinson@example.net',
#   'Male',
#   '79.253.1.116',
#   'West Stephanie'],
#  [256,
#   'Laura',
#   'Lee',
#   'vwhite@example.com',
#   'Male',
#   '47.15.212.193',
#   'West Luis'],
#  [257,
#   'Bruce',
#   'Sweeney',
#   'nicholas71@example.net',
#   'Female',
#   '91.38.169.119',
#   'West Matthewborough'],
#  [258,
#   'Francisco',
#   'Bush',
#   'rileydavid@example.net',
#   'Female',
#   '117.172.146.98',
#   'West David'],
#  [259,
#   'Tracy',
#   'Paul',
#   'ashley00@example.com',
#   'Male',
#   '45.47.54.185',
#   'Lake Samanthamouth'],
#  [260,
#   'Alex',
#   'Bryant',
#   'austinyoung@example.com',
#   'Female',
#   '190.64.211.204',
#   'Burgesston'],
#  [261,
#   'Tracey',
#   'Hale',
#   'moniqueodom@example.org',
#   'Male',
#   '25.145.207.229',
#   'Markside'],
#  [262,
#   'Wendy',
#   'Williams',
#   'soniakrause@example.org',
#   'Female',
#   '69.38.25.217',
#   'South Juliabury'],
#  [263,
#   'Christopher',
#   'Mcdonald',
#   'qmcbride@example.org',
#   'Male',
#   '41.20.252.248',
#   'Danielburgh'],
#  [264,
#   'Michele',
#   'Martinez',
#   'moodyjimmy@example.com',
#   'Male',
#   '60.69.122.27',
#   'West Melissaport'],
#  [265,
#   'Sarah',
#   'Williams',
#   'kathleen72@example.net',
#   'Male',
#   '113.235.97.238',
#   'Lawrencefort'],
#  [266,
#   'Mike',
#   'Manning',
#   'dennis61@example.net',
#   'Male',
#   '157.110.233.42',
#   'Roachfort'],
#  [267,
#   'Matthew',
#   'Gordon',
#   'toddnelson@example.net',
#   'Male',
#   '196.212.132.55',
#   'Port Andrew'],
#  [268,
#   'Eric',
#   'Harris',
#   'dustinchristensen@example.org',
#   'Male',
#   '154.15.223.67',
#   'South Jill'],
#  [269,
#   'Kyle',
#   'Osborn',
#   'jacquelinefranco@example.net',
#   'Female',
#   '142.68.215.218',
#   'North Mindy'],
#  [270,
#   'Christopher',
#   'Woods',
#   'fwright@example.net',
#   'Female',
#   '176.4.251.216',
#   'Ericton'],
#  [271,
#   'Tammy',
#   'Carroll',
#   'thendricks@example.com',
#   'Male',
#   '94.216.56.137',
#   'North Bianca'],
#  [272,
#   'Emily',
#   'Lyons',
#   'kathleen23@example.net',
#   'Male',
#   '38.106.102.240',
#   'Wheelerborough'],
#  [273,
#   'Thomas',
#   'Collier',
#   'egalvan@example.com',
#   'Male',
#   '57.122.223.60',
#   'Lake Ana'],
#  [274,
#   'Jessica',
#   'Clark',
#   'cevans@example.com',
#   'Female',
#   '168.67.37.116',
#   'Donnaville'],
#  [275,
#   'Angela',
#   'Leonard',
#   'jorge93@example.com',
#   'Male',
#   '82.57.216.65',
#   'North Sarah'],
#  [276,
#   'Kenneth',
#   'Brown',
#   'scott31@example.com',
#   'Female',
#   '218.169.254.158',
#   'North Stephanieland'],
#  [277,
#   'Amanda',
#   'Morton',
#   'sarah68@example.com',
#   'Male',
#   '59.205.215.168',
#   'North Brandonport'],
#  [278,
#   'Christopher',
#   'Morris',
#   'millermary@example.com',
#   'Male',
#   '183.165.101.131',
#   'East Katieton'],
#  [279,
#   'Brenda',
#   'Cohen',
#   'melissa59@example.com',
#   'Female',
#   '197.90.131.5',
#   'West Williamshire'],
#  [280,
#   'Regina',
#   'Flynn',
#   'amcguire@example.net',
#   'Male',
#   '185.254.246.146',
#   'Alyssaburgh'],
#  [281,
#   'James',
#   'Thomas',
#   'millertimothy@example.org',
#   'Male',
#   '29.112.98.24',
#   'Shawnbury'],
#  [282,
#   'Matthew',
#   'Parsons',
#   'coryhicks@example.com',
#   'Female',
#   '84.76.17.135',
#   'Dianeport'],
#  [283,
#   'James',
#   'Perez',
#   'uaustin@example.net',
#   'Male',
#   '117.173.90.245',
#   'Susanhaven'],
#  [284,
#   'Jennifer',
#   'Willis',
#   'jenniferkirby@example.com',
#   'Female',
#   '69.135.75.69',
#   'Lake Marymouth'],
#  [285,
#   'Craig',
#   'Henry',
#   'cparker@example.com',
#   'Female',
#   '199.197.43.147',
#   'West Jacquelinemouth'],
#  [286,
#   'David',
#   'Peterson',
#   'rachelwolfe@example.org',
#   'Female',
#   '9.42.76.103',
#   'West Maryshire'],
#  [287,
#   'Jennifer',
#   'Robertson',
#   'orichardson@example.net',
#   'Female',
#   '98.4.166.244',
#   'Joshuamouth'],
#  [288,
#   'Scott',
#   'Arellano',
#   'daniel23@example.com',
#   'Male',
#   '88.172.154.180',
#   'South Kayla'],
#  [289,
#   'Jessica',
#   'Campbell',
#   'blackjanice@example.net',
#   'Female',
#   '181.206.58.19',
#   'South Biancachester'],
#  [290,
#   'Andrea',
#   'Riley',
#   'wardmonique@example.org',
#   'Female',
#   '105.250.161.214',
#   'Shaunbury'],
#  [291,
#   'Adrian',
#   'Ford',
#   'dhart@example.org',
#   'Female',
#   '166.230.177.84',
#   'New Kaylaside'],
#  [292,
#   'Marcus',
#   'Murray',
#   'jason46@example.com',
#   'Male',
#   '134.180.30.137',
#   'Port Michael'],
#  [293,
#   'Megan',
#   'Hernandez',
#   'richard39@example.org',
#   'Female',
#   '129.90.107.162',
#   'East Diane'],
#  [294,
#   'Kelly',
#   'Harrison',
#   'sabrina15@example.net',
#   'Male',
#   '159.31.75.66',
#   'New Tammy'],
#  [295,
#   'Sharon',
#   'Woodward',
#   'carloswheeler@example.com',
#   'Male',
#   '187.214.243.159',
#   'East Ryanshire'],
#  [296,
#   'Kristi',
#   'Jordan',
#   'kbrown@example.net',
#   'Female',
#   '88.16.197.0',
#   'Port Tommy'],
#  [297,
#   'Ronnie',
#   'Morales',
#   'boothkeith@example.org',
#   'Female',
#   '151.37.186.198',
#   'New Tiffany'],
#  [298,
#   'Steven',
#   'Roy',
#   'suttonkyle@example.net',
#   'Male',
#   '140.235.234.170',
#   'Port Wayne'],
#  [299,
#   'John',
#   'Douglas',
#   'jermainehess@example.com',
#   'Male',
#   '122.211.28.187',
#   'Williamhaven'],
#  [300,
#   'Derek',
#   'Williams',
#   'mgonzalez@example.net',
#   'Female',
#   '153.234.149.126',
#   'Thomasstad'],
#  [301,
#   'Laura',
#   'Carroll',
#   'mendozanicole@example.net',
#   'Female',
#   '90.32.136.15',
#   'New Judy'],
#  [302,
#   'Kimberly',
#   'Green',
#   'april79@example.net',
#   'Female',
#   '44.242.250.58',
#   'Danielshire'],
#  [303,
#   'Emily',
#   'Sanders',
#   'stevenstammy@example.com',
#   'Male',
#   '166.154.68.163',
#   'Port Elizabeth'],
#  [304,
#   'Jeanette',
#   'Charles',
#   'carlsonfrank@example.net',
#   'Male',
#   '149.10.147.3',
#   'Alexandermouth'],
#  [305,
#   'Beverly',
#   'Young',
#   'karendean@example.org',
#   'Female',
#   '42.33.157.116',
#   'Jeanview'],
#  [306,
#   'Kelly',
#   'Martin',
#   'dorothybishop@example.org',
#   'Female',
#   '121.248.53.5',
#   'Port Brandyland'],
#  [307,
#   'Michael',
#   'Johnson',
#   'gregory68@example.net',
#   'Male',
#   '188.169.4.99',
#   'South Diana'],
#  [308,
#   'Dawn',
#   'Henderson',
#   'vwebb@example.net',
#   'Female',
#   '172.159.102.154',
#   'Dannyfort'],
#  [309,
#   'Allison',
#   'Nguyen',
#   'delgadojames@example.net',
#   'Male',
#   '125.228.72.19',
#   'South Christine'],
#  [310,
#   'Jessica',
#   'Patterson',
#   'schultzvickie@example.org',
#   'Female',
#   '32.28.200.211',
#   'Jimmyport'],
#  [311,
#   'Anthony',
#   'Smith',
#   'olopez@example.org',
#   'Female',
#   '42.41.255.31',
#   'Robertsview'],
#  [312,
#   'Krista',
#   'Sims',
#   'mjones@example.org',
#   'Female',
#   '132.203.176.214',
#   'Port Deannahaven'],
#  [313,
#   'Joshua',
#   'Foster',
#   'gjohnson@example.com',
#   'Female',
#   '215.33.134.17',
#   'North Jackieside'],
#  [314,
#   'Brooke',
#   'Austin',
#   'revans@example.net',
#   'Female',
#   '132.146.123.3',
#   'Heidiborough'],
#  [315,
#   'Jerry',
#   'Webb',
#   'lopeztracy@example.org',
#   'Male',
#   '137.135.120.92',
#   'East Audrey'],
#  [316,
#   'Chad',
#   'Mason',
#   'swolfe@example.org',
#   'Female',
#   '169.252.38.91',
#   'Lake Amy'],
#  [317,
#   'Timothy',
#   'Petty',
#   'fdiaz@example.net',
#   'Female',
#   '57.225.174.247',
#   'North Traci'],
#  [318,
#   'James',
#   'Bennett',
#   'xferguson@example.com',
#   'Male',
#   '178.246.163.106',
#   'West Michaelmouth'],
#  [319,
#   'Dawn',
#   'Pittman',
#   'lwade@example.org',
#   'Male',
#   '110.118.150.128',
#   'West Christopher'],
#  [320,
#   'Harry',
#   'Ellis',
#   'franceswheeler@example.net',
#   'Male',
#   '82.164.4.24',
#   'Port David'],
#  [321,
#   'Denise',
#   'Wilson',
#   'cheryl34@example.com',
#   'Female',
#   '20.222.68.231',
#   'South Anthonyland'],
#  [322,
#   'Deanna',
#   'Fuller',
#   'vjones@example.org',
#   'Male',
#   '35.62.164.249',
#   'Lake Heatherchester'],
#  [323,
#   'Gary',
#   'Powers',
#   'holly48@example.net',
#   'Male',
#   '184.6.142.84',
#   'Perezmouth'],
#  [324,
#   'Traci',
#   'Riddle',
#   'jayhurst@example.org',
#   'Male',
#   '76.167.203.197',
#   'South Maureenfurt'],
#  [325,
#   'Richard',
#   'Lara',
#   'andersonrobert@example.org',
#   'Male',
#   '205.188.106.67',
#   'New Cathy'],
#  [326,
#   'Michael',
#   'Adams',
#   'jmiranda@example.org',
#   'Female',
#   '132.202.244.210',
#   'East Joshua'],
#  [327,
#   'Chelsea',
#   'Reyes',
#   'sheila92@example.net',
#   'Female',
#   '117.178.121.15',
#   'Port Matthew'],
#  [328,
#   'Louis',
#   'Brown',
#   'charles34@example.com',
#   'Male',
#   '45.169.241.0',
#   'North Monicafurt'],
#  [329,
#   'Tracey',
#   'Johnston',
#   'urobbins@example.org',
#   'Female',
#   '181.154.71.201',
#   'Melissaville'],
#  [330,
#   'William',
#   'Bell',
#   'jasonhendrix@example.org',
#   'Female',
#   '25.82.231.137',
#   'Karenhaven'],
#  [331,
#   'Carrie',
#   'Mills',
#   'pamela29@example.com',
#   'Male',
#   '223.12.48.130',
#   'Toddfort'],
#  [332,
#   'Michelle',
#   'Abbott',
#   'emilyweber@example.com',
#   'Female',
#   '157.46.173.212',
#   'Velasquezchester'],
#  [333,
#   'Betty',
#   'Jones',
#   'vangmark@example.com',
#   'Male',
#   '49.192.210.249',
#   'South Gloria'],
#  [334,
#   'Anthony',
#   'Smith',
#   'royheather@example.org',
#   'Female',
#   '99.3.187.154',
#   'Seanmouth'],
#  [335,
#   'Nicholas',
#   'Rivas',
#   'lisa24@example.org',
#   'Male',
#   '40.232.2.5',
#   'Robertsville'],
#  [336,
#   'Edward',
#   'Lucas',
#   'pdrake@example.com',
#   'Male',
#   '169.105.52.235',
#   'New Haileyhaven'],
#  [337,
#   'Nathan',
#   'Hayes',
#   'bnichols@example.org',
#   'Female',
#   '59.110.44.15',
#   'North Jonathan'],
#  [338,
#   'Jessica',
#   'Powell',
#   'ashley61@example.net',
#   'Female',
#   '36.160.197.66',
#   'West Diamondmouth'],
#  [339,
#   'Alexis',
#   'Tucker',
#   'myersvictor@example.net',
#   'Female',
#   '57.145.101.76',
#   'Port Samuelport'],
#  [340,
#   'Frederick',
#   'Smith',
#   'adamsdanielle@example.org',
#   'Female',
#   '136.224.175.223',
#   'Port Katelynborough'],
#  [341,
#   'Nicole',
#   'Scott',
#   'blackjoseph@example.org',
#   'Female',
#   '97.100.125.30',
#   'Gilbertburgh'],
#  [342,
#   'James',
#   'Welch',
#   'wardrobert@example.net',
#   'Male',
#   '102.47.239.217',
#   'Nelsonshire'],
#  [343,
#   'Jeremy',
#   'Wiley',
#   'rnorris@example.org',
#   'Female',
#   '147.118.220.86',
#   'Sethtown'],
#  [344,
#   'Henry',
#   'Davis',
#   'travisrobertson@example.net',
#   'Female',
#   '60.178.123.81',
#   'Josebury'],
#  [345,
#   'Rebecca',
#   'Soto',
#   'michaelmercado@example.net',
#   'Female',
#   '75.146.48.201',
#   'Campbellmouth'],
#  [346,
#   'Robert',
#   'Jones',
#   'tylercarolyn@example.org',
#   'Male',
#   '161.0.54.186',
#   'Jonathanfort'],
#  [347,
#   'Matthew',
#   'Carter',
#   'blackkenneth@example.org',
#   'Female',
#   '9.195.28.13',
#   'Deborahbury'],
#  [348,
#   'Matthew',
#   'Baker',
#   'feliciawright@example.org',
#   'Female',
#   '4.46.20.86',
#   'New Veronica'],
#  [349,
#   'Nancy',
#   'Hunt',
#   'matthew53@example.com',
#   'Male',
#   '83.50.120.133',
#   'Brettburgh'],
#  [350,
#   'Stephen',
#   'Shepard',
#   'virginiacarpenter@example.net',
#   'Female',
#   '192.173.204.29',
#   'Reneeport'],
#  [351,
#   'Nicole',
#   'Walker',
#   'kellydavis@example.net',
#   'Male',
#   '73.75.50.107',
#   'Rodriguezberg'],
#  [352,
#   'Sue',
#   'Valdez',
#   'adrianbryant@example.com',
#   'Female',
#   '58.98.94.203',
#   'Lake Tracey'],
#  [353,
#   'Thomas',
#   'Vincent',
#   'sharon81@example.org',
#   'Female',
#   '122.176.63.63',
#   'Ramosstad'],
#  [354,
#   'Randy',
#   'Crawford',
#   'erin31@example.com',
#   'Female',
#   '219.20.121.92',
#   'Robinsonmouth'],
#  [355,
#   'Bradley',
#   'Rivera',
#   'zsims@example.net',
#   'Female',
#   '16.102.213.94',
#   'Solisborough'],
#  [356,
#   'Glen',
#   'Chambers',
#   'martinezwilliam@example.net',
#   'Male',
#   '129.137.215.144',
#   'Lake Melissa'],
#  [357,
#   'Christina',
#   'Thompson',
#   'nrivas@example.org',
#   'Female',
#   '111.55.18.99',
#   'Carrhaven'],
#  [358,
#   'Kendra',
#   'Schroeder',
#   'kristinhunt@example.org',
#   'Female',
#   '143.0.190.94',
#   'Port Jessica'],
#  [359,
#   'Sandra',
#   'West',
#   'zrobinson@example.org',
#   'Male',
#   '106.21.134.32',
#   'Shannonmouth'],
#  [360,
#   'Lauren',
#   'Rodriguez',
#   'rodriguezkristin@example.org',
#   'Male',
#   '148.60.201.130',
#   'North Steveside'],
#  [361,
#   'Amy',
#   'Mayo',
#   'qcook@example.org',
#   'Male',
#   '3.164.233.107',
#   'Josephborough'],
#  [362,
#   'Albert',
#   'Thompson',
#   'justin61@example.org',
#   'Female',
#   '217.186.20.52',
#   'Brittanyfurt'],
#  [363,
#   'Leslie',
#   'Jackson',
#   'rojasamanda@example.net',
#   'Male',
#   '26.253.208.147',
#   'Jonathanport'],
#  [364,
#   'Kayla',
#   'Salinas',
#   'mortonsamuel@example.net',
#   'Male',
#   '12.160.154.107',
#   'Brandtland'],
#  [365,
#   'Natalie',
#   'Anderson',
#   'edwin99@example.com',
#   'Male',
#   '60.224.54.164',
#   'Johnburgh'],
#  [366,
#   'Mark',
#   'Miller',
#   'leesharon@example.net',
#   'Male',
#   '9.225.155.126',
#   'North Jordan'],
#  [367,
#   'Dawn',
#   'Savage',
#   'hestrada@example.com',
#   'Female',
#   '15.77.2.221',
#   'Williamsshire'],
#  [368,
#   'William',
#   'Santos',
#   'luke73@example.net',
#   'Female',
#   '55.57.1.236',
#   'New Anthonyside'],
#  [369,
#   'Michael',
#   'Merritt',
#   'scottphillips@example.net',
#   'Female',
#   '120.16.22.75',
#   'Lake David'],
#  [370,
#   'Alexis',
#   'Davis',
#   'patrick27@example.org',
#   'Female',
#   '24.140.8.202',
#   'Micheleport'],
#  [371,
#   'Stephanie',
#   'Brown',
#   'williamsshannon@example.net',
#   'Male',
#   '217.101.15.125',
#   'Lake Davidshire'],
#  [372,
#   'Kathryn',
#   'Reyes',
#   'erin39@example.com',
#   'Male',
#   '39.73.219.102',
#   'Port Nicole'],
#  [373,
#   'Amy',
#   'Robinson',
#   'ahuber@example.net',
#   'Female',
#   '199.92.110.146',
#   'Litown'],
#  [374,
#   'Paul',
#   'Murphy',
#   'peter01@example.net',
#   'Male',
#   '29.87.56.19',
#   'Mitchellburgh'],
#  [375,
#   'Christopher',
#   'Brown',
#   'ssmith@example.com',
#   'Male',
#   '195.177.240.34',
#   'North Cynthiaberg'],
#  [376,
#   'Christopher',
#   'Garcia',
#   'millerdavid@example.org',
#   'Male',
#   '87.178.169.120',
#   'West Chelsea'],
#  [377,
#   'Lucas',
#   'Bennett',
#   'jonesstacey@example.com',
#   'Female',
#   '106.225.49.14',
#   'Colemanmouth'],
#  [378,
#   'Karen',
#   'Allen',
#   'anthonymurphy@example.com',
#   'Male',
#   '2.34.39.193',
#   'South Robertview'],
#  [379,
#   'John',
#   'Adams',
#   'phillip54@example.com',
#   'Female',
#   '206.128.232.180',
#   'East Victoria'],
#  [380,
#   'Ricardo',
#   'Love',
#   'ericawilliams@example.org',
#   'Female',
#   '178.214.52.225',
#   'North William'],
#  [381,
#   'Curtis',
#   'Randall',
#   'bakerjeanne@example.net',
#   'Male',
#   '41.97.210.121',
#   'North Heathermouth'],
#  [382,
#   'Donna',
#   'Lam',
#   'dakota36@example.com',
#   'Male',
#   '27.38.183.206',
#   'Jasonport'],
#  [383,
#   'Nancy',
#   'Robbins',
#   'grantchristina@example.org',
#   'Female',
#   '110.128.92.165',
#   'Port Derek'],
#  [384,
#   'Michelle',
#   'Williams',
#   'trodgers@example.com',
#   'Male',
#   '151.139.169.7',
#   'Millertown'],
#  [385,
#   'Cindy',
#   'Sparks',
#   'popeaaron@example.net',
#   'Male',
#   '44.249.1.109',
#   'Port Charles'],
#  [386,
#   'Katherine',
#   'Torres',
#   'brian39@example.com',
#   'Female',
#   '173.225.114.224',
#   'Lake Melissaport'],
#  [387,
#   'Kristin',
#   'Gregory',
#   'leonard20@example.net',
#   'Male',
#   '56.197.123.103',
#   'South Pamela'],
#  [388,
#   'Heidi',
#   'Reid',
#   'marcuscain@example.com',
#   'Female',
#   '194.214.247.61',
#   'West Shawnaport'],
#  [389,
#   'Douglas',
#   'Bell',
#   'henry33@example.net',
#   'Male',
#   '110.167.155.141',
#   'Lake Donnaland'],
#  [390,
#   'Mary',
#   'Coffey',
#   'john56@example.com',
#   'Male',
#   '13.216.38.79',
#   'Port Holly'],
#  [391,
#   'Mindy',
#   'Nelson',
#   'michaelwells@example.com',
#   'Female',
#   '37.99.64.158',
#   'Martinmouth'],
#  [392,
#   'William',
#   'Jones',
#   'ronaldvega@example.org',
#   'Female',
#   '19.83.196.162',
#   'South Candaceport'],
#  [393,
#   'Daniel',
#   'Powell',
#   'ramirezmatthew@example.com',
#   'Male',
#   '216.48.135.95',
#   'Port Michelle'],
#  [394,
#   'Alyssa',
#   'Brewer',
#   'thomas56@example.org',
#   'Male',
#   '122.106.36.220',
#   'Heathermouth'],
#  [395,
#   'Russell',
#   'King',
#   'bchavez@example.net',
#   'Female',
#   '43.14.168.196',
#   'West Maryside'],
#  [396,
#   'Martin',
#   'Williams',
#   'clevy@example.net',
#   'Female',
#   '133.28.21.245',
#   'Mcdonaldton'],
#  [397,
#   'Misty',
#   'Bailey',
#   'colemanaaron@example.net',
#   'Female',
#   '25.193.35.246',
#   'Zacharyport'],
#  [398,
#   'Michael',
#   'Robinson',
#   'rebecca28@example.net',
#   'Male',
#   '5.191.168.203',
#   'New Jennifer'],
#  [399,
#   'Hector',
#   'Hughes',
#   'brownmark@example.net',
#   'Female',
#   '39.84.145.30',
#   'Lake Natashafurt'],
#  [400,
#   'Jose',
#   'Butler',
#   'ngray@example.org',
#   'Male',
#   '4.10.178.75',
#   'East Jessica'],
#  [401,
#   'Kristina',
#   'Allen',
#   'leontimothy@example.org',
#   'Female',
#   '203.7.75.80',
#   'Carlastad'],
#  [402,
#   'Danielle',
#   'Hunter',
#   'kellerkristina@example.org',
#   'Female',
#   '213.141.78.20',
#   'Port Randyfurt'],
#  [403,
#   'Joshua',
#   'Daniels',
#   'shirley72@example.net',
#   'Female',
#   '66.74.33.135',
#   'Aguilarhaven'],
#  [404,
#   'Jennifer',
#   'Ochoa',
#   'madisondurham@example.com',
#   'Male',
#   '112.183.56.250',
#   'Snowfort'],
#  [405,
#   'Teresa',
#   'Carpenter',
#   'cduarte@example.com',
#   'Male',
#   '124.54.52.230',
#   'Carterport'],
#  [406,
#   'Meghan',
#   'Lopez',
#   'lopezmark@example.net',
#   'Female',
#   '25.211.131.38',
#   'Jensentown'],
#  [407,
#   'Tamara',
#   'Wagner',
#   'anthony44@example.com',
#   'Male',
#   '218.109.195.249',
#   'Port Olivia'],
#  [408,
#   'Katherine',
#   'Johnson',
#   'meghan43@example.org',
#   'Female',
#   '137.15.30.185',
#   'Manningmouth'],
#  [409,
#   'Luke',
#   'Doyle',
#   'phillipsjames@example.net',
#   'Male',
#   '164.224.65.3',
#   'East Waynefort'],
#  [410,
#   'David',
#   'Garrett',
#   'reedjohn@example.com',
#   'Male',
#   '152.143.112.253',
#   'Susanborough'],
#  [411,
#   'Robert',
#   'Edwards',
#   'qmullen@example.net',
#   'Female',
#   '217.219.3.158',
#   'North Andrewtown'],
#  [412,
#   'Michelle',
#   'Bruce',
#   'zjackson@example.net',
#   'Male',
#   '71.102.197.43',
#   'West Chadhaven'],
#  [413,
#   'Brian',
#   'Morse',
#   'stacey20@example.net',
#   'Female',
#   '16.62.36.196',
#   'Port Alexander'],
#  [414,
#   'Cory',
#   'Crawford',
#   'changlinda@example.org',
#   'Male',
#   '140.190.85.235',
#   'North James'],
#  [415,
#   'Zachary',
#   'Evans',
#   'jamesevans@example.com',
#   'Male',
#   '15.215.242.214',
#   'West Johnburgh'],
#  [416,
#   'Jessica',
#   'Rogers',
#   'lowenancy@example.com',
#   'Male',
#   '111.45.79.203',
#   'Martinmouth'],
#  [417,
#   'Amber',
#   'Wood',
#   'tylerchristopher@example.com',
#   'Male',
#   '22.210.114.111',
#   'Port Steveside'],
#  [418,
#   'Cassidy',
#   'Kennedy',
#   'harpermichael@example.org',
#   'Female',
#   '215.15.231.214',
#   'East Rebecca'],
#  [419,
#   'Kathleen',
#   'Bradley',
#   'sharoncruz@example.com',
#   'Male',
#   '216.15.245.82',
#   'Flemingberg'],
#  [420,
#   'Ashlee',
#   'Parsons',
#   'mercedesbaker@example.net',
#   'Female',
#   '120.144.2.107',
#   'Kylefurt'],
#  [421,
#   'Kimberly',
#   'Daniels',
#   'wwong@example.org',
#   'Female',
#   '124.3.238.236',
#   'South Audreyview'],
#  [422,
#   'Mary',
#   'Clarke',
#   'mcdonaldrita@example.com',
#   'Female',
#   '172.89.163.220',
#   'Charlesmouth'],
#  [423,
#   'James',
#   'Jackson',
#   'nicole71@example.net',
#   'Female',
#   '181.24.217.103',
#   'Sarahton'],
#  [424,
#   'Ryan',
#   'Carter',
#   'emilywilcox@example.net',
#   'Female',
#   '33.245.136.195',
#   'Lake Tonya'],
#  [425,
#   'Joyce',
#   'Taylor',
#   'christopher72@example.org',
#   'Female',
#   '72.26.136.44',
#   'South Michaelbury'],
#  [426,
#   'Cathy',
#   'Howell',
#   'brittanywheeler@example.org',
#   'Female',
#   '146.231.228.1',
#   'New Victoriaburgh'],
#  [427,
#   'Hayley',
#   'Johnson',
#   'lukeabbott@example.com',
#   'Male',
#   '168.136.171.84',
#   'West Davidfurt'],
#  [428,
#   'Derrick',
#   'Cummings',
#   'jonsparks@example.net',
#   'Male',
#   '179.236.241.154',
#   'Lake Mike'],
#  [429,
#   'David',
#   'Santos',
#   'evanssarah@example.org',
#   'Female',
#   '37.171.227.210',
#   'Smithfurt'],
#  [430,
#   'Molly',
#   'Ibarra',
#   'jason96@example.com',
#   'Male',
#   '132.239.51.126',
#   'Carloston'],
#  [431,
#   'Andrea',
#   'Olsen',
#   'tina98@example.net',
#   'Male',
#   '172.6.117.101',
#   'South Andrew'],
#  [432,
#   'Edgar',
#   'Thompson',
#   'fitzgeraldmichelle@example.com',
#   'Male',
#   '221.241.30.74',
#   'Maryport'],
#  [433,
#   'Andrew',
#   'Carter',
#   'copelandsean@example.net',
#   'Female',
#   '191.197.163.147',
#   'Wilkinsburgh'],
#  [434,
#   'Lynn',
#   'Bright',
#   'connercharles@example.net',
#   'Male',
#   '53.206.59.139',
#   'Jasonport'],
#  [435,
#   'Robert',
#   'Smith',
#   'madisongomez@example.com',
#   'Male',
#   '63.11.157.12',
#   'Mariemouth'],
#  [436,
#   'Michelle',
#   'Thompson',
#   'fordjason@example.net',
#   'Male',
#   '179.227.74.22',
#   'Christinemouth'],
#  [437,
#   'Jacob',
#   'Doyle',
#   'powerskelly@example.net',
#   'Female',
#   '223.60.163.200',
#   'Moorefort'],
#  [438,
#   'Jessica',
#   'Bauer',
#   'rarmstrong@example.org',
#   'Male',
#   '103.184.118.54',
#   'South Sean'],
#  [439,
#   'Alexander',
#   'Robinson',
#   'karen42@example.com',
#   'Female',
#   '168.84.138.32',
#   'Cisnerosport'],
#  [440,
#   'Debra',
#   'Sweeney',
#   'paul90@example.com',
#   'Female',
#   '195.228.41.148',
#   'Sarahshire'],
#  [441,
#   'Greg',
#   'Vargas',
#   'joeestes@example.com',
#   'Female',
#   '17.236.42.91',
#   'Port Jenniferchester'],
#  [442,
#   'Nancy',
#   'Wilcox',
#   'nancyholt@example.org',
#   'Female',
#   '68.181.84.59',
#   'Lopezfurt'],
#  [443,
#   'Brandon',
#   'Woodard',
#   'frankglass@example.net',
#   'Male',
#   '176.207.178.111',
#   'Lake Pamela'],
#  [444,
#   'Christopher',
#   'Williams',
#   'leblancnancy@example.org',
#   'Male',
#   '63.79.5.237',
#   'South Traci'],
#  [445,
#   'Patrick',
#   'Monroe',
#   'wardsteve@example.net',
#   'Female',
#   '157.198.179.42',
#   'North Jamesstad'],
# ...
#   'thomas78@example.org',
#   'Male',
#   '76.220.138.229',
#   'South Paul'],
#  [855,
#   'Lisa',
#   'Johnson',
#   'karensnyder@example.net',
#   'Male',
#   '11.176.45.142',
#   'Johnstonhaven'],
#  [856,
#   'Kristie',
#   'Allen',
#   'thompsonjeremy@example.org',
#   'Female',
#   '41.188.213.55',
#   'Lake Jamesmouth'],
#  [857,
#   'Shawn',
#   'Horne',
#   'barnesjoshua@example.org',
#   'Female',
#   '26.243.103.2',
#   'South Virginiaberg'],
#  [858,
#   'Sharon',
#   'Johnson',
#   'larrydillon@example.net',
#   'Female',
#   '60.36.194.242',
#   'Seanstad'],
#  [859,
#   'Devin',
#   'Christensen',
#   'handerson@example.net',
#   'Female',
#   '55.118.144.216',
#   'New Jonathan'],
#  [860,
#   'Sandra',
#   'Garcia',
#   'peckjulie@example.org',
#   'Female',
#   '190.220.73.32',
#   'Lake Timothyfurt'],
#  [861,
#   'Jordan',
#   'Orr',
#   'zarnold@example.org',
#   'Male',
#   '82.76.2.69',
#   'Laurenfort'],
#  [862,
#   'Eric',
#   'Campbell',
#   'isosa@example.net',
#   'Female',
#   '126.125.202.10',
#   'Hintonfurt'],
#  [863,
#   'Donald',
#   'Lynch',
#   'xmontgomery@example.net',
#   'Male',
#   '211.32.184.102',
#   'East Davidborough'],
#  [864,
#   'Tracy',
#   'Johnson',
#   'kristajones@example.com',
#   'Female',
#   '92.176.112.118',
#   'Williammouth'],
#  [865,
#   'Tammy',
#   'Brown',
#   'allenmichael@example.org',
#   'Male',
#   '11.98.93.157',
#   'Port Lorettaside'],
#  [866,
#   'Linda',
#   'Martin',
#   'ecabrera@example.net',
#   'Female',
#   '21.119.88.220',
#   'Lake Jason'],
#  [867,
#   'David',
#   'Wiggins',
#   'fostershawn@example.com',
#   'Male',
#   '78.134.64.203',
#   'Lake Jefferyview'],
#  [868,
#   'Kelly',
#   'Edwards',
#   'vickie18@example.net',
#   'Male',
#   '207.18.108.46',
#   'Nathanmouth'],
#  [869,
#   'John',
#   'Fletcher',
#   'kaitlinmay@example.net',
#   'Female',
#   '89.67.78.55',
#   'West Joyce'],
#  [870,
#   'Debra',
#   'Guerra',
#   'geraldgaines@example.org',
#   'Male',
#   '190.51.120.129',
#   'East Cameronfurt'],
#  [871,
#   'Michael',
#   'Burgess',
#   'katie58@example.org',
#   'Female',
#   '192.210.144.190',
#   'Gutierrezfurt'],
#  [872,
#   'Kendra',
#   'Miller',
#   'mmurphy@example.com',
#   'Female',
#   '31.65.248.119',
#   'Brownchester'],
#  [873,
#   'Katrina',
#   'Bradshaw',
#   'adamsheather@example.net',
#   'Female',
#   '161.113.139.133',
#   'Port Eric'],
#  [874,
#   'Amber',
#   'Brady',
#   'carloslewis@example.org',
#   'Female',
#   '46.142.190.194',
#   'West Lindsey'],
#  [875,
#   'Tracy',
#   'Wilson',
#   'hpham@example.org',
#   'Female',
#   '19.136.240.24',
#   'Collinschester'],
#  [876,
#   'Troy',
#   'Figueroa',
#   'andrewfischer@example.org',
#   'Male',
#   '120.59.169.217',
#   'North Valerieberg'],
#  [877,
#   'Amanda',
#   'Farley',
#   'burkemisty@example.com',
#   'Female',
#   '134.9.78.253',
#   'New Michellemouth'],
#  [878,
#   'Andrew',
#   'Diaz',
#   'pberry@example.net',
#   'Female',
#   '68.233.143.176',
#   'Port Andrew'],
#  [879,
#   'Timothy',
#   'Robbins',
#   'tstephens@example.net',
#   'Female',
#   '54.174.20.224',
#   'Weaverburgh'],
#  [880,
#   'Yolanda',
#   'Duncan',
#   'petersonnancy@example.org',
#   'Female',
#   '122.204.136.210',
#   'Michaelmouth'],
#  [881,
#   'Justin',
#   'Martinez',
#   'rebeccaperkins@example.net',
#   'Male',
#   '43.134.129.133',
#   'Brownview'],
#  [882,
#   'Cody',
#   'Russell',
#   'vkelly@example.net',
#   'Female',
#   '125.160.127.12',
#   'West Barbara'],
#  [883,
#   'Michael',
#   'Scott',
#   'sophiacordova@example.org',
#   'Female',
#   '98.100.224.149',
#   'Chelseaview'],
#  [884,
#   'Christina',
#   'Ortiz',
#   'cummingscarla@example.com',
#   'Female',
#   '122.224.173.39',
#   'North Chad'],
#  [885,
#   'Stefanie',
#   'Johnson',
#   'pmoses@example.org',
#   'Female',
#   '148.47.42.85',
#   'Jensenview'],
#  [886,
#   'Nicholas',
#   'Sanchez',
#   'pamelaanderson@example.net',
#   'Male',
#   '200.239.119.221',
#   'Lake Mariah'],
#  [887,
#   'Michelle',
#   'Diaz',
#   'egibson@example.org',
#   'Female',
#   '157.79.10.13',
#   'Lake Lawrenceland'],
#  [888,
#   'Damon',
#   'Weiss',
#   'kevin83@example.net',
#   'Female',
#   '133.227.62.203',
#   'East Jennifer'],
#  [889,
#   'Kathleen',
#   'Martinez',
#   'ucooper@example.net',
#   'Male',
#   '167.101.194.208',
#   'Larastad'],
#  [890,
#   'Karen',
#   'Turner',
#   'christinahuang@example.net',
#   'Male',
#   '220.111.117.153',
#   'New Cheryl'],
#  [891,
#   'Timothy',
#   'Glenn',
#   'ssmith@example.com',
#   'Male',
#   '207.95.90.65',
#   'Rodgersshire'],
#  [892,
#   'Kristin',
#   'Norman',
#   'terryralph@example.com',
#   'Male',
#   '14.118.224.42',
#   'Danielmouth'],
#  [893,
#   'Nicole',
#   'Joseph',
#   'hernandezronald@example.org',
#   'Male',
#   '176.221.33.123',
#   'Myersshire'],
#  [894,
#   'Diana',
#   'Miller',
#   'xtaylor@example.net',
#   'Female',
#   '6.175.164.42',
#   'Michaelhaven'],
#  [895,
#   'Christopher',
#   'Miller',
#   'robinsonchristine@example.org',
#   'Male',
#   '114.70.16.235',
#   'Lake Karenmouth'],
#  [896,
#   'Gregory',
#   'Rush',
#   'jim65@example.com',
#   'Male',
#   '47.136.111.50',
#   'Port Jennaburgh'],
#  [897,
#   'Danny',
#   'Fuller',
#   'sperez@example.net',
#   'Male',
#   '198.195.84.111',
#   'West Jeremyside'],
#  [898,
#   'Joseph',
#   'Cooper',
#   'qbooker@example.com',
#   'Male',
#   '23.103.245.185',
#   'Elizabethhaven'],
#  [899,
#   'Jennifer',
#   'Wong',
#   'xrobinson@example.net',
#   'Female',
#   '157.223.178.255',
#   'Toddstad'],
#  [900,
#   'Darlene',
#   'Riley',
#   'joseph89@example.com',
#   'Male',
#   '44.118.217.191',
#   'North Stephaniehaven'],
#  [901,
#   'Kelly',
#   'Martinez',
#   'ibarracolleen@example.com',
#   'Male',
#   '39.46.168.211',
#   'West Linda'],
#  [902,
#   'Paul',
#   'Carr',
#   'peggypeters@example.com',
#   'Male',
#   '143.246.8.58',
#   'Smithborough'],
#  [903,
#   'Patricia',
#   'Powers',
#   'panderson@example.org',
#   'Female',
#   '189.233.207.201',
#   'Maciashaven'],
#  [904,
#   'Peter',
#   'Ortiz',
#   'robertsimmons@example.org',
#   'Male',
#   '75.93.70.175',
#   'Sabrinaland'],
#  [905,
#   'Robert',
#   'Reynolds',
#   'scott05@example.com',
#   'Male',
#   '72.230.149.37',
#   'Christinehaven'],
#  [906,
#   'Christopher',
#   'Powell',
#   'daniel82@example.com',
#   'Male',
#   '156.50.155.17',
#   'Robertchester'],
#  [907,
#   'Jeffrey',
#   'Marshall',
#   'monicaalvarado@example.com',
#   'Female',
#   '102.254.240.242',
#   'New Michael'],
#  [908,
#   'Tracey',
#   'Mccullough',
#   'donaldmcdonald@example.com',
#   'Female',
#   '188.205.234.34',
#   'New Beth'],
#  [909,
#   'Kathleen',
#   'Jackson',
#   'orrchelsea@example.com',
#   'Female',
#   '137.156.106.246',
#   'Dillonland'],
#  [910,
#   'Nicholas',
#   'Hernandez',
#   'ecross@example.org',
#   'Female',
#   '123.32.122.102',
#   'West Trevorview'],
#  [911,
#   'Elizabeth',
#   'Gomez',
#   'joseph09@example.net',
#   'Male',
#   '116.37.139.4',
#   'Sherryview'],
#  [912,
#   'Mary',
#   'Bender',
#   'hwoods@example.net',
#   'Female',
#   '20.191.199.38',
#   'Daltonfort'],
#  [913,
#   'Robert',
#   'French',
#   'pamelajohnson@example.com',
#   'Male',
#   '185.138.126.107',
#   'North Amytown'],
#  [914,
#   'Rachel',
#   'Rose',
#   'joe50@example.com',
#   'Female',
#   '49.238.2.106',
#   'East Nichole'],
#  [915,
#   'Jennifer',
#   'Cruz',
#   'thompsonjanice@example.net',
#   'Female',
#   '55.167.176.185',
#   'Port Rachelhaven'],
#  [916,
#   'David',
#   'Kelly',
#   'wendy19@example.com',
#   'Female',
#   '210.181.217.151',
#   'Lake Omarview'],
#  [917,
#   'Chelsea',
#   'Coleman',
#   'walkerroy@example.org',
#   'Male',
#   '99.30.137.128',
#   'Burkeshire'],
#  [918,
#   'Casey',
#   'Zimmerman',
#   'rdavis@example.com',
#   'Female',
#   '214.212.158.44',
#   'North Lisa'],
#  [919,
#   'Robert',
#   'Roberts',
#   'kingdawn@example.com',
#   'Female',
#   '219.186.24.125',
#   'Port Amy'],
#  [920,
#   'Jane',
#   'Hawkins',
#   'neallaura@example.net',
#   'Male',
#   '40.224.223.77',
#   'Port Hayley'],
#  [921,
#   'Bradley',
#   'Martinez',
#   'richardbishop@example.net',
#   'Female',
#   '89.158.187.127',
#   'Michaelberg'],
#  [922,
#   'Daniel',
#   'Turner',
#   'alexandria33@example.org',
#   'Female',
#   '171.12.66.0',
#   'New Destinytown'],
#  [923,
#   'Aaron',
#   'Vasquez',
#   'mindywright@example.com',
#   'Female',
#   '197.28.27.254',
#   'East Joshuamouth'],
#  [924,
#   'Emily',
#   'Hoffman',
#   'laura88@example.com',
#   'Female',
#   '108.131.23.84',
#   'Desireefort'],
#  [925,
#   'Derek',
#   'Mclaughlin',
#   'reidcody@example.org',
#   'Male',
#   '54.231.207.24',
#   'Lake Meganville'],
#  [926,
#   'Traci',
#   'Murphy',
#   'emily37@example.org',
#   'Female',
#   '78.12.233.123',
#   'West Leslie'],
#  [927,
#   'Kristin',
#   'Vasquez',
#   'kristine22@example.org',
#   'Female',
#   '57.78.49.77',
#   'Desireeborough'],
#  [928,
#   'Beverly',
#   'Sloan',
#   'amandaortiz@example.com',
#   'Female',
#   '14.152.190.209',
#   'Port Tarashire'],
#  [929,
#   'Janet',
#   'Black',
#   'ashleyherrera@example.com',
#   'Male',
#   '5.73.111.196',
#   'Blankenshiptown'],
#  [930,
#   'Rachel',
#   'Trevino',
#   'haynesleah@example.com',
#   'Male',
#   '107.54.44.58',
#   'Carolynhaven'],
#  [931,
#   'Stephanie',
#   'Nicholson',
#   'urobinson@example.com',
#   'Male',
#   '215.249.187.205',
#   'New Donnamouth'],
#  [932,
#   'Christopher',
#   'Rodriguez',
#   'stephanie01@example.net',
#   'Female',
#   '91.244.79.185',
#   'Lake Daniel'],
#  [933,
#   'Laura',
#   'Simpson',
#   'ylowery@example.net',
#   'Male',
#   '14.254.219.123',
#   'Leonardborough'],
#  [934,
#   'Michael',
#   'Rodriguez',
#   'danieldonna@example.net',
#   'Male',
#   '6.77.89.98',
#   'East Chad'],
#  [935,
#   'Rachael',
#   'Lopez',
#   'qrobertson@example.com',
#   'Female',
#   '94.146.157.171',
#   'Ginamouth'],
#  [936,
#   'Regina',
#   'Rodgers',
#   'sharonyoung@example.net',
#   'Male',
#   '125.41.64.99',
#   'Stuartside'],
#  [937,
#   'Raymond',
#   'Banks',
#   'joshuahouse@example.net',
#   'Female',
#   '157.242.32.195',
#   'Port Jacquelinefurt'],
#  [938,
#   'Abigail',
#   'George',
#   'robinsonleonard@example.net',
#   'Female',
#   '206.206.108.72',
#   'South Scott'],
#  [939,
#   'Brittany',
#   'Savage',
#   'petersenrobert@example.org',
#   'Female',
#   '102.71.133.121',
#   'Williamsonview'],
#  [940,
#   'Tiffany',
#   'James',
#   'fjohnson@example.com',
#   'Female',
#   '58.151.163.142',
#   'West Daniel'],
#  [941,
#   'Charles',
#   'Garza',
#   'diane45@example.com',
#   'Male',
#   '188.53.191.229',
#   'Port Prestonside'],
#  [942,
#   'Marissa',
#   'French',
#   'rward@example.net',
#   'Male',
#   '74.106.73.247',
#   'Rachelberg'],
#  [943,
#   'Taylor',
#   'Murphy',
#   'hinesrandy@example.org',
#   'Male',
#   '68.2.176.200',
#   'Mauricefurt'],
#  [944,
#   'Valerie',
#   'Watkins',
#   'martinezmichael@example.net',
#   'Female',
#   '3.231.36.61',
#   'South Jessica'],
#  [945,
#   'George',
#   'Lopez',
#   'nortonbryan@example.net',
#   'Female',
#   '110.66.151.198',
#   'Ryanborough'],
#  [946,
#   'Megan',
#   'Wade',
#   'jasmine02@example.com',
#   'Male',
#   '220.223.65.2',
#   'Farmerburgh'],
#  [947,
#   'Stephanie',
#   'Baker',
#   'dhill@example.net',
#   'Female',
#   '104.76.236.189',
#   'West Ericshire'],
#  [948,
#   'Amanda',
#   'Taylor',
#   'lisa71@example.com',
#   'Female',
#   '163.11.160.252',
#   'Robertsside'],
#  [949,
#   'David',
#   'Hall',
#   'qsparks@example.net',
#   'Female',
#   '167.155.42.106',
#   'Meganbury'],
#  [950,
#   'Erik',
#   'Smith',
#   'justinbarron@example.net',
#   'Female',
#   '216.222.45.117',
#   'Masonburgh'],
#  [951,
#   'Karina',
#   'Hanson',
#   'tracey02@example.com',
#   'Male',
#   '108.73.11.205',
#   'South Alejandro'],
#  [952,
#   'Nancy',
#   'Flores',
#   'gsweeney@example.net',
#   'Male',
#   '219.70.237.219',
#   'New Cathyborough'],
#  [953,
#   'Andrea',
#   'Logan',
#   'dennis53@example.com',
#   'Male',
#   '140.145.179.206',
#   'South Michaelburgh'],
#  [954,
#   'Amy',
#   'Vaughn',
#   'ronald71@example.org',
#   'Female',
#   '25.230.188.195',
#   'Williamborough'],
#  [955,
#   'Erica',
#   'Johnson',
#   'dustinanderson@example.org',
#   'Male',
#   '216.155.37.103',
#   'North Scottstad'],
#  [956,
#   'Mike',
#   'Mendoza',
#   'mannpatricia@example.com',
#   'Female',
#   '113.127.178.138',
#   'Mckenziehaven'],
#  [957,
#   'George',
#   'Lee',
#   'griffithjesse@example.net',
#   'Female',
#   '180.252.223.89',
#   'Sandrachester'],
#  [958,
#   'Kristen',
#   'Black',
#   'john93@example.net',
#   'Female',
#   '198.118.162.48',
#   'Lake David'],
#  [959,
#   'Gabriel',
#   'Henderson',
#   'tlee@example.net',
#   'Male',
#   '7.115.147.71',
#   'Knoxbury'],
#  [960,
#   'Heather',
#   'Leonard',
#   'olopez@example.org',
#   'Female',
#   '135.62.255.90',
#   'South Coreystad'],
#  [961,
#   'Kelli',
#   'Richmond',
#   'denisebrown@example.org',
#   'Female',
#   '194.34.10.2',
#   'Graybury'],
#  [962,
#   'John',
#   'Nelson',
#   'murraycheryl@example.org',
#   'Male',
#   '113.103.239.84',
#   'Kingside'],
#  [963,
#   'David',
#   'Barron',
#   'brandonharris@example.com',
#   'Female',
#   '119.24.121.67',
#   'New Donald'],
#  [964,
#   'Sharon',
#   'Pugh',
#   'anngamble@example.net',
#   'Female',
#   '104.186.92.198',
#   'Danielton'],
#  [965,
#   'Zachary',
#   'Moore',
#   'stephanieberger@example.com',
#   'Male',
#   '115.59.25.163',
#   'East Laurenburgh'],
#  [966,
#   'Jennifer',
#   'Ortiz',
#   'suarezbenjamin@example.org',
#   'Male',
#   '201.180.63.247',
#   'Port Richard'],
#  [967,
#   'William',
#   'Combs',
#   'longbrandon@example.org',
#   'Female',
#   '120.240.86.187',
#   'Thompsonland'],
#  [968,
#   'Julie',
#   'Swanson',
#   'michelle53@example.net',
#   'Female',
#   '14.82.37.161',
#   'Alexandraberg'],
#  [969,
#   'Haley',
#   'Snow',
#   'luke07@example.com',
#   'Male',
#   '76.166.241.145',
#   'New Jonathan'],
#  [970,
#   'William',
#   'Wang',
#   'jessica03@example.org',
#   'Female',
#   '162.252.13.130',
#   'Dustintown'],
#  [971,
#   'Holly',
#   'Weber',
#   'millerjulia@example.com',
#   'Male',
#   '181.250.100.67',
#   'Amberton'],
#  [972,
#   'Laura',
#   'Jackson',
#   'juliegreene@example.net',
#   'Female',
#   '212.55.236.46',
#   'Port Julieberg'],
#  [973,
#   'Ethan',
#   'Sims',
#   'kathy78@example.org',
#   'Female',
#   '11.213.108.255',
#   'Spencertown'],
#  [974,
#   'Bruce',
#   'Hunt',
#   'diazbrian@example.net',
#   'Male',
#   '49.139.6.166',
#   'Port Jennifer'],
#  [975,
#   'Danielle',
#   'Kelly',
#   'grayjesus@example.net',
#   'Female',
#   '134.254.133.8',
#   'Williamchester'],
#  [976,
#   'Jo',
#   'Hall',
#   'jjones@example.net',
#   'Male',
#   '139.178.118.121',
#   'East Marciaview'],
#  [977,
#   'Rhonda',
#   'Larson',
#   'tiffany62@example.org',
#   'Male',
#   '33.233.196.134',
#   'Hammondburgh'],
#  [978,
#   'Bryan',
#   'Jones',
#   'uperez@example.org',
#   'Male',
#   '212.9.160.176',
#   'Danielmouth'],
#  [979,
#   'Nancy',
#   'Franklin',
#   'gallaghertamara@example.net',
#   'Female',
#   '175.199.49.91',
#   'West Jadefurt'],
#  [980,
#   'Joanne',
#   'Baker',
#   'andreagray@example.org',
#   'Female',
#   '13.163.127.216',
#   'Chandlerburgh'],
#  [981,
#   'Gabriel',
#   'Maxwell',
#   'gibbschelsea@example.com',
#   'Female',
#   '205.25.246.34',
#   'Lake Hannahland'],
#  [982,
#   'Kurt',
#   'Schultz',
#   'joshua92@example.com',
#   'Male',
#   '187.161.121.232',
#   'Juliamouth'],
#  [983,
#   'Gregory',
#   'Pham',
#   'jennifer08@example.net',
#   'Female',
#   '66.191.17.131',
#   'East Jaimeburgh'],
#  [984,
#   'Penny',
#   'Davis',
#   'nancymorrison@example.org',
#   'Female',
#   '86.64.189.177',
#   'West Bianca'],
#  [985,
#   'Megan',
#   'Harris',
#   'harmonkaren@example.com',
#   'Female',
#   '26.127.192.155',
#   'Reginaborough'],
#  [986,
#   'Shelly',
#   'Lawson',
#   'natalieking@example.com',
#   'Female',
#   '117.48.243.211',
#   'Samanthaland'],
#  [987,
#   'Lisa',
#   'Hall',
#   'madisonsaunders@example.net',
#   'Female',
#   '97.40.42.43',
#   'Scottton'],
#  [988,
#   'Hunter',
#   'Evans',
#   'williamblevins@example.net',
#   'Male',
#   '38.155.206.121',
#   'Sandraborough'],
#  [989,
#   'Justin',
#   'Gonzalez',
#   'ekelley@example.com',
#   'Male',
#   '161.110.91.11',
#   'Joneshaven'],
#  [990,
#   'Patrick',
#   'Wallace',
#   'shawnkirby@example.com',
#   'Male',
#   '84.224.254.163',
#   'Lake Tara'],
#  [991,
#   'Christopher',
#   'Compton',
#   'josephbrown@example.net',
#   'Male',
#   '147.210.174.161',
#   'North Charlesstad'],
#  [992,
#   'Andrew',
#   'Cross',
#   'cbell@example.org',
#   'Female',
#   '184.54.116.146',
#   'Lake Timothyfort'],
#  [993,
#   'Gloria',
#   'Harris',
#   'rsmith@example.net',
#   'Female',
#   '171.176.84.225',
#   'East Michaelstad'],
#  [994,
#   'Kristie',
#   'Turner',
#   'javierjohnson@example.com',
#   'Male',
#   '33.231.124.224',
#   'Kathrynville'],
#  [995,
#   'Juan',
#   'Mccann',
#   'josephmitchell@example.com',
#   'Female',
#   '195.160.194.150',
#   'South Kevinmouth'],
#  [996,
#   'Brenda',
#   'Ray',
#   'robertweaver@example.com',
#   'Male',
#   '40.108.184.28',
#   'New Elijah'],
#  [997,
#   'Joshua',
#   'Wilkerson',
#   'vbrowning@example.org',
#   'Female',
#   '11.222.142.44',
#   'West Michelleborough'],
#  [998,
#   'Joshua',
#   'Johnson',
#   'brooksmitchell@example.net',
#   'Male',
#   '77.197.86.187',
#   'West Susanport'],
#  [999,
#   'Stephanie',
#   'Oconnor',
#   'paul04@example.net',
#   'Female',
#   '21.42.188.154',
#   'Bradfordburgh'],
#  [1000,
#   'Jennifer',
#   'Bowers',
#   'daletorres@example.org',
#   'Female',
#   '185.195.125.180',
#   'Lyonsberg'],
#  ...]

# %%
# Escrever os dados para um arquivo CSV
with open('dados.csv', mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(headers)  # Escrever os headers
    writer.writerows(data)    # Escrever os dados

# %% [markdown]
# Neste exemplo:
# - Utilizamos a biblioteca `csv` para trabalhar com arquivos CSV.
# - Utilizamos a biblioteca `faker` para gerar dados falsos, como nomes, endereços de e-mail, IP e cidades.
# - Geramos 2000 linhas de dados aleatórios, cada uma com um ID, primeiro nome, sobrenome, e-mail, gênero, endereço IP e cidade.
# - Escrevemos os dados para um arquivo CSV chamado `dados.csv`, com os headers na primeira linha.

# %% [markdown]
# ____
# ## Lendo arquivos CSV

# %%
import csv

# %% [markdown]
# Ao passar o caminho do arquivo, certifique-se de incluir a extensão se houver uma. Você deve ser capaz de usar o recurso de autocompletar com a tecla Tab para o nome do arquivo. Se você não conseguir usar o autocompletar, é um bom indicador de que o arquivo não está na mesma localização do seu caderno. Você sempre pode digitar o caminho completo do arquivo (ele terá um formato semelhante à saída de **pwd**).

# %%
data = open('dados.csv')

# %%
data
# Out:
# <_io.TextIOWrapper name='dados.csv' mode='r' encoding='cp1252'>

# %% [markdown]
# ### Encoding
#
# Frequentemente, arquivos CSV podem conter caracteres que não podem ser interpretados com o Python padrão, como o símbolo **@**, ou mesmo caracteres estrangeiros. Vamos ver um exemplo desse tipo de erro ([isso é bastante comum, por isso é importante revisar](https://stackoverflow.com/questions/9233027/unicodedecodeerror-charmap-codec-cant-decode-byte-x-in-position-y-character)).

# %%
csv_data = csv.reader(data)

# %% [markdown]
# Converter para uma lista causará um erro, observe a linha **can't decode** no erro, isso indica que temos um problema de codificação!

# %%
data_lines = list(csv_data)

# %% [markdown]
# Let's not try reading it with a "utf-8" encoding.

# %%
data = open('dados.csv',encoding="utf-8")
csv_data = csv.reader(data)
data_lines = list(csv_data)

# %%
# Parece que funcionou!
data_lines[:3]
# Out:
# [['id', 'first_name', 'last_name', 'email', 'gender', 'ip_address', 'city'],
#  ['1',
#   'April',
#   'Hoffman',
#   'harellano@example.com',
#   'Male',
#   '186.225.13.96',
#   'Crystalfort'],
#  ['2',
#   'Katrina',
#   'Lindsey',
#   'hwalker@example.org',
#   'Female',
#   '88.239.81.222',
#   'New Scottburgh']]

# %% [markdown]
# Nota: O primeiro item da lista é a linha do cabeçalho, isso contém as informações sobre o que cada coluna representa. Vamos formatar nosso print um pouco:

# %%
for line in data_lines[:5]:
    print(line)
# Out:
# ['id', 'first_name', 'last_name', 'email', 'gender', 'ip_address', 'city']
# ['1', 'April', 'Hoffman', 'harellano@example.com', 'Male', '186.225.13.96', 'Crystalfort']
# ['2', 'Katrina', 'Lindsey', 'hwalker@example.org', 'Female', '88.239.81.222', 'New Scottburgh']
# ['3', 'Kevin', 'Johnston', 'randysalazar@example.net', 'Female', '143.219.166.160', 'Port Danielmouth']
# ['4', 'Kenneth', 'Garcia', 'kayla30@example.com', 'Male', '44.69.180.6', 'Meganhaven']

# %%
len(data_lines)
# Out:
# 2001

# %%
all_emails = []
for line in data_lines[1:15]:
    all_emails.append(line[3])

# %%
print(all_emails)
# Out:
# ['harellano@example.com', 'hwalker@example.org', 'randysalazar@example.net', 'kayla30@example.com', 'charlesanita@example.org', 'ibenton@example.org', 'lisasanders@example.org', 'ejones@example.net', 'proberts@example.org', 'wattsbryan@example.net', 'ryanroberson@example.com', 'thomas59@example.net', 'patrick18@example.org', 'justinharrell@example.org']

# %% [markdown]
# E se quiséssemos uma lista de nomes completos?

# %%
full_names = []

for line in data_lines[1:15]:
    full_names.append(line[1]+' '+line[2])

# %%
full_names
# Out:
# ['April Hoffman',
#  'Katrina Lindsey',
#  'Kevin Johnston',
#  'Kenneth Garcia',
#  'Randy Medina',
#  'Martha Kelly',
#  'Daniel Dean',
#  'Tracy Clark',
#  'Laurie Walls',
#  'Dawn Lynch',
#  'Ryan Yang',
#  'William Ayers',
#  'David Bailey',
#  'Andrea Johnson']

# %% [markdown]
# ### Arquivo Novo
# Também podemos escrever arquivos CSV, seja novos ou adicionando a arquivos existentes.

# %%
# newline controla como as novas linhas são definidas
# Pode ser None, '', '\n', '\r', e '\r\n'.
file_to_output = open('to_save_file.csv','w',newline='')

# %%
csv_writer = csv.writer(file_to_output,delimiter=',')

# %%
csv_writer.writerow(['a','b','c'])
# Out:
# 7

# %%
csv_writer.writerows([['1','2','3'],['4','5','6']])

# %%
file_to_output.close()

# %% [markdown]
# ____
# ### Arquivo existente

# %%
f = open('to_save_file.csv','a',newline='')

# %%
csv_writer = csv.writer(f)

# %%
csv_writer.writerow(['new','new','new'])
# Out:
# 13

# %%
f.close()

# %% [markdown]
#  ## Criando arquivos em excel e tratando com Pandas
#
#  Certifique-se de que você tenha a biblioteca pandas instalada em seu ambiente antes de executar este código:

# %%
# !pip install pandas
# !pip install openpyxl
# Out:
# Requirement already satisfied: pandas in c:\python312\lib\site-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.26.0 in c:\python312\lib\site-packages (from pandas) (1.26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\henriquefrank\appdata\roaming\python\python312\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\python312\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\python312\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\henriquefrank\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting openpyxl
#   Downloading openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
#      ---------------------------------------- 0.0/250.0 kB ? eta -:--:--
#      ---------------------------------------- 0.0/250.0 kB ? eta -:--:--
#      ------------------ ------------------- 122.9/250.0 kB 7.5 MB/s eta 0:00:01
#      -------------------------------------- 250.0/250.0 kB 5.1 MB/s eta 0:00:00
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.2
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# Crie um DataFrame com alguns dados
data = {'Nome': ['João', 'Maria', 'Carlos', 'Ana'],
        'Idade': [25, 30, 22, 28],
        'Cidade': ['São Paulo', 'Rio de Janeiro', 'Belo Horizonte', 'Porto Alegre']}

df = pd.DataFrame(data)

# Especifique o nome do arquivo Excel que você deseja criar
nome_arquivo = 'dados_pessoas.xlsx'

# Salve o DataFrame no arquivo Excel
df.to_excel(nome_arquivo, index=False)

print(f'Arquivo Excel "{nome_arquivo}" criado com sucesso.')
# Out:
# Arquivo Excel "dados_pessoas.xlsx" criado com sucesso.

# %% [markdown]
# Neste código, estamos criando um DataFrame usando a biblioteca pandas e, em seguida, usando o método to_excel() para salvar os dados em um arquivo Excel com o nome "dados.xlsx". Certifique-se de que o arquivo "dados.xlsx" será criado no diretório em que seu script está sendo executado.
#
# Depois de executar o código, você deve encontrar o arquivo Excel no mesmo diretório em que o script foi executado.

# %% [markdown]
# Certamente! Vou mostrar como você pode realizar um tratamento simples dos dados no DataFrame usando a biblioteca pandas. Neste exemplo, faremos o seguinte:
#
# Calcular a média das idades.
# Encontrar a pessoa mais velha.
# Classificar o DataFrame por idade em ordem decrescente.
# Aqui está o código:

# %%
# 1. Calcular a média das idades
media_idades = df['Idade'].mean()
print(f'Média das idades: {media_idades} anos')
# Out:
# Média das idades: 26.25 anos

# %%
# 2. Encontrar a pessoa mais velha
pessoa_mais_velha = df[df['Idade'] == df['Idade'].max()]
print(f'Pessoa mais velha:\n{pessoa_mais_velha}')
# Out:
# Pessoa mais velha:
#     Nome  Idade          Cidade
# 1  Maria     30  Rio de Janeiro

# %%
# 3. Classificar o DataFrame por idade em ordem decrescente
df_ordenado = df.sort_values(by='Idade', ascending=False)
print('DataFrame ordenado por idade em ordem decrescente:')
print(df_ordenado)
# Out:
# DataFrame ordenado por idade em ordem decrescente:
#      Nome  Idade          Cidade
# 1   Maria     30  Rio de Janeiro
# 3     Ana     28    Porto Alegre
# 0    João     25       São Paulo
# 2  Carlos     22  Belo Horizonte
