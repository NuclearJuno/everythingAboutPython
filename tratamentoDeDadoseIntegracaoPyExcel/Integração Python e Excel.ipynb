# %%
import pandas as pd

# %%
base_vendas = pd.read_excel('D:/ESTUDOS/git/everythingAboutPython/tratamentoDeDadoseIntegraçãoPy&Excel/src/BaseVendas.xlsx', skiprows=1, sheet_name='Vendas')
base_vendas.head()
# Out:
#    Unnamed: 0       Data  Quantidade  ID do Produto  ID do Comprador  \
# 0         NaN 2020-01-01           6              7               27
# 1         NaN 2020-01-02           1             10               21
# 2         NaN 2020-01-03           6              1                4
# 3         NaN 2020-01-04          10              5                6
# 4         NaN 2020-01-05           2              6               10
#
#    ID da Loja  Valor Total da Compra
# 0           3               25194.00
# 1           1                  62.90
# 2          10               56994.00
# 3           9               47040.00
# 4          10                6839.82

# %%
base_vendas = base_vendas.drop('Unnamed: 0', axis=1)
base_vendas
# Out:
#           Data  Quantidade  ID do Produto  ID do Comprador  ID da Loja  \
# 0   2020-01-01           6              7               27           3
# 1   2020-01-02           1             10               21           1
# 2   2020-01-03           6              1                4          10
# 3   2020-01-04          10              5                6           9
# 4   2020-01-05           2              6               10          10
# ..         ...         ...            ...              ...         ...
# 726 2021-12-27           6             12               18           1
# 727 2021-12-28           2              9               17           3
# 728 2021-12-29           4              2               26           6
# 729 2021-12-30           6             10                6           2
# 730 2021-12-31           8              1               17           7
#
#      Valor Total da Compra
# 0                 25194.00
# 1                    62.90
# 2                 56994.00
# ...

# %%
base_vendas.columns
# Out:
# Index(['Data', 'Quantidade', 'ID do Produto', 'ID do Comprador', 'ID da Loja',
#        'Valor Total da Compra'],
#       dtype='object')

# %%
base_vendas[['Data', 'Quantidade', 'ID do Produto', 'Valor Total da Compra']]
# Out:
#           Data  Quantidade  ID do Produto  Valor Total da Compra
# 0   2020-01-01           6              7               25194.00
# 1   2020-01-02           1             10                  62.90
# 2   2020-01-03           6              1               56994.00
# 3   2020-01-04          10              5               47040.00
# 4   2020-01-05           2              6                6839.82
# ..         ...         ...            ...                    ...
# 726 2021-12-27           6             12                 312.00
# 727 2021-12-28           2              9                 138.00
# 728 2021-12-29           4              2               15994.80
# 729 2021-12-30           6             10                 377.40
# 730 2021-12-31           8              1               75992.00
#
# [731 rows x 4 columns]

# %%
base_produtos = pd.read_excel('D:/ESTUDOS/git/everythingAboutPython/tratamentoDeDadoseIntegraçãoPy&Excel/src/BaseProdutos.xlsx',skiprows= 1)
base_produtos.drop('Unnamed: 0',axis=1,inplace=True)
base_produtos
# Out:
#     ID do Produto                           Nome do Produto        Marca  \
# 0               1                             iPhone 13 Pro        Apple
# 1               2                                Galaxy S21      Samsung
# 2               3                                 Boombox 2          JBL
# 3               4                     Echo Dot (3ª Geração)       Amazon
# 4               5                       Lava e Seca 10,1 kg     Brastemp
# 5               6  Lavadora de Roupas Digital Inverter 11kg     Samsung
# 6               7                 Lava Louças Ciclo Pesado      Brastemp
# 7               8                    Lava-Louças 8 Serviços   Electrolux
# 8               9         Smart Lâmpada Inteligente EWS 407    Intelbras
# 9              10      Smart Lâmpada Wi-Fi Casa Inteligente     Positivo
# 10             11            Mouse Gamer G203 LIGHTSYNC RGB    Logitech
# 11             12               Mouse Gamer com Fio 3200DPI  Multilaser
#
# ...

# %%
base_vendas_produtos = base_vendas.merge(base_produtos, on='ID do Produto', how='left')

# %%
df = base_vendas_produtos[['Data', 'Quantidade', 'Valor Total da Compra', 'Preço' ]]
df.head()
# Out:
#         Data  Quantidade  Valor Total da Compra    Preço
# 0 2020-01-01           6               25194.00  4199.00
# 1 2020-01-02           1                  62.90    62.90
# 2 2020-01-03           6               56994.00  9499.00
# 3 2020-01-04          10               47040.00  4704.00
# 4 2020-01-05           2                6839.82  3419.91

# %%
df['Preço Calculado'] = df['Quantidade'] * df['Preço']
df.head()
# Out:
# C:\Users\juno\AppData\Local\Temp\ipykernel_13528\3661261665.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Preço Calculado'] = df['Quantidade'] * df['Preço']
#         Data  Quantidade  Valor Total da Compra    Preço  Preço Calculado
# 0 2020-01-01           6               25194.00  4199.00         25194.00
# 1 2020-01-02           1                  62.90    62.90            62.90
# 2 2020-01-03           6               56994.00  9499.00         56994.00
# 3 2020-01-04          10               47040.00  4704.00         47040.00
# 4 2020-01-05           2                6839.82  3419.91          6839.82

# %%
path= 'D:/ESTUDOS/git/everythingAboutPython/tratamentoDeDadoseIntegraçãoPy&Excel/src/'

# %%
df.to_excel(path + 'Tabela Produtos e Vendas.xlsx', sheet_name='Tabela 1')

# %%
base_lojas = pd.read_excel('D:/ESTUDOS/git/everythingAboutPython/tratamentoDeDadoseIntegraçãoPy&Excel/src/BaseLojas.xlsx',skiprows= 1)
base_lojas.drop('Unnamed: 0',axis=1,inplace=True)
base_lojas
# Out:
#    ID da Loja                                  Rua       CEP           Bairro  \
# 0           1                 Rua Barão de Vitória   9961660      Casa Grande
# 1           2                         Rua Paracatu   4302021  Parque Imperial
# 2           3                 Rua Arlindo Nogueira  64000290           Centro
# 3           4                  Rua Cristiano Olsen  16015244    Jardim Sumaré
# 4           5                      Rua dos Carijós  30120060           Centro
# 5           6                  Avenida Afonso Pena  30130005       Boa Viagem
# 6           7          Rua Tenente-Coronel Cardoso  28035042           Centro
# 7           8      Avenida Governador José Malcher  66055260           Nazaré
# 8           9  Avenida Esbertalina Barbosa Damiani  29946490     Guriri Norte
# 9          10         Rua Carlos Augusto Cornelsen  80520560       Bom Retiro
#
#                   Cidade Estado
# 0                Diadema     SP
# 1              São Paulo     SP
# ...

# %%
base_lojas.tail(2)
# Out:
#    ID da Loja                                  Rua       CEP        Bairro  \
# 8           9  Avenida Esbertalina Barbosa Damiani  29946490  Guriri Norte
# 9          10         Rua Carlos Augusto Cornelsen  80520560    Bom Retiro
#
#        Cidade Estado
# 8  São Mateus     ES
# 9    Curitiba     PR

# %%
base_compradores = pd.read_excel('D:/ESTUDOS/git/everythingAboutPython/tratamentoDeDadoseIntegraçãoPy&Excel/src/BaseCompradores.xlsx',skiprows= 1)
base_compradores.drop(['Unnamed: 0','Column1', ],axis=1,inplace=True)
base_compradores.tail(10)
# Out:
#     ID do Comprador     Nome Completo      Nome Sobrenome Sobrenome2  \
# 29             30.0  Bernardo Pereira  Bernardo   Pereira        NaN
# 30              NaN                         NaN       NaN        NaN
# 31              NaN                         NaN       NaN        NaN
# 32              NaN                         NaN       NaN        NaN
# 33              NaN                         NaN       NaN        NaN
# 34              NaN                         NaN       NaN        NaN
# 35              NaN                         NaN       NaN        NaN
# 36              NaN                         NaN       NaN        NaN
# 37              NaN                         NaN       NaN        NaN
# 38              NaN
#
#                         E-mail Idade Número Total de Compras
# 29  Bernardo.Pereira@gmail.com    36                       4
# 30                         NaN   NaN                     NaN
# 31                         NaN   NaN                     NaN
# ...

# %%
base_compradores = base_compradores[base_compradores['ID do Comprador'].notna()]

# %%
base_compradores = base_compradores[['ID do Comprador','Nome Completo', 'Idade']]

# %%
base_completa = base_vendas_produtos.merge(base_compradores, on='ID do Comprador', how='left')
base_completa.head()
# Out:
#         Data  Quantidade  ID do Produto  ID do Comprador  ID da Loja  \
# 0 2020-01-01           6              7               27           3
# 1 2020-01-02           1             10               21           1
# 2 2020-01-03           6              1                4          10
# 3 2020-01-04          10              5                6           9
# 4 2020-01-05           2              6               10          10
#
#    Valor Total da Compra                           Nome do Produto     Marca  \
# 0               25194.00                 Lava Louças Ciclo Pesado   Brastemp
# 1                  62.90      Smart Lâmpada Wi-Fi Casa Inteligente  Positivo
# 2               56994.00                             iPhone 13 Pro     Apple
# 3               47040.00                       Lava e Seca 10,1 kg  Brastemp
# 4                6839.82  Lavadora de Roupas Digital Inverter 11kg  Samsung
#
#   Cor do Produto    Preço         Categoria     Sub-categoria  Estoque  \
# ...

# %%
base_lojas = base_lojas[['ID da Loja', 'Cidade', 'Estado']]

# %%
base_completa = base_completa.merge(base_lojas, on= 'ID da Loja', how='left')
base_completa.head()
# Out:
#         Data  Quantidade  ID do Produto  ID do Comprador  ID da Loja  \
# 0 2020-01-01           6              7               27           3
# 1 2020-01-02           1             10               21           1
# 2 2020-01-03           6              1                4          10
# 3 2020-01-04          10              5                6           9
# 4 2020-01-05           2              6               10          10
#
#    Valor Total da Compra                           Nome do Produto     Marca  \
# 0               25194.00                 Lava Louças Ciclo Pesado   Brastemp
# 1                  62.90      Smart Lâmpada Wi-Fi Casa Inteligente  Positivo
# 2               56994.00                             iPhone 13 Pro     Apple
# 3               47040.00                       Lava e Seca 10,1 kg  Brastemp
# 4                6839.82  Lavadora de Roupas Digital Inverter 11kg  Samsung
#
#   Cor do Produto    Preço         Categoria     Sub-categoria  Estoque  \
# ...

# %%
base_completa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Data                   731 non-null    datetime64[ns]
#  1   Quantidade             731 non-null    int64
#  2   ID do Produto          731 non-null    int64
#  3   ID do Comprador        731 non-null    int64
#  4   ID da Loja             731 non-null    int64
#  5   Valor Total da Compra  731 non-null    float64
#  6   Nome do Produto        731 non-null    object
#  7   Marca                  731 non-null    object
#  8   Cor do Produto         731 non-null    object
#  9   Preço                  731 non-null    float64
#  10  Categoria              731 non-null    object
#  11  Sub-categoria          731 non-null    object
#  12  Estoque                731 non-null    int64
#  13  Nome Completo          731 non-null    object
# ...

# %%
base_completa[['Quantidade', 'Preço', 'Valor Total da Compra']].describe().T
# Out:
#                        count          mean           std   min    25%  \
# Quantidade             731.0      5.380301      2.877469   1.0    3.0
# Preço                  731.0   2603.019343   2733.743016  52.0   69.0
# Valor Total da Compra  731.0  14316.466607  19228.292960  52.0  503.2
#
#                            50%       75%      max
# Quantidade                5.00      8.00     10.0
# Preço                  2470.63   3998.70   9499.0
# Valor Total da Compra  6839.82  22235.67  94990.0

# %%
path= 'D:/ESTUDOS/git/everythingAboutPython/tratamentoDeDadoseIntegraçãoPy&Excel/src/'

# %%
base_completa.to_excel(path + 'Base_Completa.xlsx', sheet_name='Base Completa de Vendas')
